# %%
from metabolinks import align, read_aligned_spectra, read_spectra_from_xcel
from metabolinks.similarity import mz_similarity

# %% [markdown]
# ### Similarity analysis with data used being the following peak alignments "Non-Bias":
# #### 1 - 1st alignment: min_sample = 1, 2nd alignment: min_sample = 6 - NAME: 1-6
# #### 2 - 1st alignment: min_sample = 1, 2nd alignment: min_sample = 13 - NAME: 1-13
#
# All further changes to code will first be implemented on the original similarity_analysis. This is an altered version of said original.
#
# To better understand the functions used outside of normal Python packages, see scaling.py and multianalysis.py where they are better described and try tosay what is happening in each block of code.

# %% [markdown]
# ## Similarity analysis
#
# aligned_all_neg = negative dataset alignment 1-6 / aligned_neg - binary matrix equivalent
#
# aligned_all_pos = positive dataset alignment 1-6 / aligned_pos - binary matrix equivalent
#
# aligned_all_neg2 = negative dataset alignment 1-13 / aligned_neg2 - binary matrix equivalent
#
# aligned_all_pos2 = positive dataset alignment 1-13 / aligned_pos2 - binary matrix equivalent

# %% [markdown]
# #### Read aligned data, using peaks that appear in at least 2 samples

# %%
aligned_all_pos = read_aligned_spectra('aligned_1ppm_min1-6_1ppm_positive.csv', labels=True, sep=',')
aligned_all_neg = read_aligned_spectra('aligned_1ppm_min1-6_1ppm_negative.csv', labels=True, sep=',')
#print('------ positive mode aligned --------------')
#print(aligned_all_pos.info())
#print('------ negative mode aligned --------------')
#print(aligned_all_neg.info())

# %% [markdown]
# #### Compute m/z similarities

# %%
sim_pos = mz_similarity(aligned_all_pos)
sim_neg = mz_similarity(aligned_all_neg)

# %%
print(sim_pos)
# Out:
# Sample similarity, counts of common peaks
#           14   15   16   29   30   31    8    9   10   23  ...    34  10713-1  \
# 14       339  252  229  213  217  199  210  209  213  162  ...   183       15
# 15       252  477  270  291  287  286  254  251  257  236  ...   268       17
# 16       229  270  366  246  239  240  210  212  222  188  ...   214       17
# 29       213  291  246  652  443  463  259  258  264  319  ...   370       22
# 30       217  287  239  443  630  417  272  264  261  304  ...   365       23
# 31       199  286  240  463  417  640  247  262  263  302  ...   373       24
# 8        210  254  210  259  272  247  427  296  298  204  ...   241       11
# 9        209  251  212  258  264  262  296  438  314  219  ...   245       19
# 10       213  257  222  264  261  263  298  314  459  218  ...   266       18
# 23       162  236  188  319  304  302  204  219  218  763  ...   456       29
# 24       170  239  192  333  311  320  209  221  228  634  ...   479       28
# 25       158  232  181  316  305  316  191  218  216  591  ...   475       29
# 38       189  264  205  385  363  379  243  243  264  503  ...   775       28
# 39       189  269  212  388  372  392  244  234  262  496  ...   788       24
# 40       185  263  211  387  366  376  251  250  265  494  ...   777       26
# 17       172  214  191  212  215  214  201  211  213  189  ...   230       18
# 18       191  217  197  218  232  213  205  208  224  182  ...   201       16
# 19       132  151  144  161  156  165  143  144  152  115  ...   149       13
# 26       209  284  233  389  373  396  236  236  266  317  ...   399       24
# 27       231  298  257  438  409  416  262  272  276  344  ...   431       24
# 28       233  310  244  404  392  385  262  280  286  356  ...   400       27
# 20       160  195  174  188  181  191  172  175  180  155  ...   191       20
# 21       143  166  152  158  159  157  156  155  165  129  ...   162       19
# 22       144  168  166  165  170  165  149  148  157  134  ...   160       13
# 35       185  257  203  372  358  372  230  227  254  467  ...   721       26
# 36       193  268  206  382  362  379  242  237  267  496  ...   755       27
# 37       187  256  201  369  368  359  233  234  261  502  ...   766       26
# 32       198  273  218  370  358  357  233  236  253  449  ...   781       26
# 33       188  266  223  393  363  389  243  247  265  448  ...   842       29
# 34       183  268  214  370  365  373  241  245  266  456  ...  1048       27
# 10713-1   15   17   17   22   23   24   11   19   18   29  ...    27      107
# 10713-2   13   18   15   21   23   22   13   18   19   25  ...    29       76
# 10713-3   15   21   19   27   28   27   15   19   24   37  ...    39       80
# 13514-1    7    7    8   14    9   12    5    7   14   12  ...    21       47
# 13514-2    6    5    5    8    8    6    4    6    9    9  ...    10       37
# 13514-3   11   11   10   16   14   14    9    9   13   13  ...    18       55
# 53211-1   10    8   10   13   11   13    8   13   19   17  ...    15       66
# 53211-2   10    9    8   15   16   16   12   19   17   20  ...    19       57
# 53211-3    9    8    8   15   14   13    8   13   14   20  ...    17       62
#
#          10713-2  10713-3  13514-1  13514-2  13514-3  53211-1  53211-2  \
# 14            13       15        7        6       11       10       10
# 15            18       21        7        5       11        8        9
# 16            15       19        8        5       10       10        8
# 29            21       27       14        8       16       13       15
# 30            23       28        9        8       14       11       16
# 31            22       27       12        6       14       13       16
# 8             13       15        5        4        9        8       12
# 9             18       19        7        6        9       13       19
# 10            19       24       14        9       13       19       17
# 23            25       37       12        9       13       17       20
# 24            27       38       13        8       12       16       22
# 25            28       41       15        8       14       15       20
# 38            27       35       22       10       14       12       15
# 39            23       34       17       11       15       12       16
# 40            26       33       20       10       14       16       18
# 17            17       24       11        8       14       14       13
# 18            19       19        9        6       10       14       11
# 19            13       19        9        7        7       11        9
# 26            17       27       16        9       14       11       16
# 27            17       28       13        9       14       10       16
# 28            19       31       15        8       13       11       16
# 20            21       20        9        8       14       13       13
# 21            18       20        6        5       10       12       11
# 22            12       14       10        8       14       12       11
# 35            25       36       16        7       11       19       21
# 36            23       35       12        8       12       16       19
# 37            24       36       18        9       15       18       21
# 32            26       37       20        7       14       13       18
# 33            27       38       21        8       14       15       18
# 34            29       39       21       10       18       15       19
# 10713-1       76       80       47       37       55       66       57
# 10713-2      105       85       45       39       54       69       55
# 10713-3       85      121       51       41       56       68       58
# 13514-1       45       51       76       40       48       48       39
# 13514-2       39       41       40       57       43       43       36
# 13514-3       54       56       48       43       84       58       53
# 53211-1       69       68       48       43       58       94       70
# 53211-2       55       58       39       36       53       70       89
# 53211-3       58       60       40       38       56       68       66
#
#          53211-3
# 14             9
# 15             8
# 16             8
# 29            15
# 30            14
# 31            13
# 8              8
# 9             13
# 10            14
# 23            20
# 24            20
# 25            19
# 38            14
# 39            17
# 40            17
# 17            11
# 18            12
# 19             8
# 26            12
# 27            14
# 28            14
# 20            14
# 21            12
# 22            12
# 35            19
# 36            21
# 37            18
# 32            20
# 33            17
# 34            17
# 10713-1       62
# 10713-2       58
# 10713-3       60
# 13514-1       40
# 13514-2       38
# 13514-3       56
# 53211-1       68
# 53211-2       66
# 53211-3       90
#
# [39 rows x 39 columns]
#
# Sample similarity, Jaccard indexes
#                14        15        16        29        30        31         8  \
# 14       1.000000  0.446809  0.481092  0.273779  0.288564  0.255128  0.377698
# 15       0.446809  1.000000  0.471204  0.347255  0.350000  0.344164  0.390769
# 16       0.481092  0.471204  1.000000  0.318653  0.315720  0.313316  0.360206
# 29       0.273779  0.347255  0.318653  1.000000  0.528010  0.558504  0.315854
# 30       0.288564  0.350000  0.315720  0.528010  1.000000  0.488863  0.346497
# 31       0.255128  0.344164  0.313316  0.558504  0.488863  1.000000  0.301220
# 8        0.377698  0.390769  0.360206  0.315854  0.346497  0.301220  1.000000
# 9        0.367958  0.378012  0.358108  0.310096  0.328358  0.321078  0.520211
# 10       0.364103  0.378498  0.368159  0.311688  0.315217  0.314593  0.506803
# 23       0.172340  0.235060  0.199787  0.291058  0.279155  0.274296  0.206897
# 24       0.175620  0.230473  0.197328  0.297853  0.278175  0.285970  0.205506
# 25       0.164071  0.225901  0.187177  0.282648  0.275519  0.285714  0.187623
# 38       0.149881  0.199396  0.161164  0.279390  0.263425  0.276239  0.187645
# 39       0.147772  0.201197  0.165238  0.278536  0.268205  0.284677  0.185976
# 40       0.147410  0.200000  0.167994  0.283309  0.268132  0.275458  0.196554
# 17       0.319703  0.337539  0.349817  0.261406  0.273537  0.268507  0.336683
# 18       0.379722  0.352846  0.375954  0.276299  0.308101  0.272379  0.355286
# 19       0.302752  0.272072  0.319290  0.223611  0.221906  0.234375  0.278752
# 26       0.266242  0.334906  0.295685  0.423747  0.408991  0.440489  0.278960
# 27       0.272727  0.324619  0.303066  0.459601  0.426042  0.431983  0.289823
# 28       0.293821  0.362998  0.301607  0.432086  0.423784  0.408705  0.307512
# 20       0.329218  0.331070  0.348697  0.243839  0.239418  0.252646  0.306050
# 21       0.315673  0.292254  0.322718  0.210386  0.218407  0.212162  0.295455
# 22       0.322148  0.299465  0.367257  0.223275  0.238764  0.226960  0.281132
# 35       0.155462  0.204618  0.169308  0.282675  0.273700  0.285276  0.186537
# 36       0.153907  0.203493  0.162461  0.277213  0.263081  0.276844  0.187162
# 37       0.151540  0.196470  0.161187  0.270330  0.273810  0.263390  0.182602
# 32       0.172926  0.225993  0.189236  0.287714  0.280564  0.277389  0.194491
# 33       0.154988  0.208955  0.185062  0.297502  0.273138  0.296268  0.195024
# 34       0.151993  0.213206  0.178333  0.278195  0.277989  0.283650  0.195300
# 10713-1  0.034803  0.029982  0.037281  0.029851  0.032213  0.033195  0.021033
# 10713-2  0.030162  0.031915  0.032895  0.028533  0.032303  0.030429  0.025048
# 10713-3  0.033708  0.036395  0.040598  0.036193  0.038728  0.036785  0.028143
# 13514-1  0.017157  0.012821  0.018433  0.019608  0.012912  0.017045  0.010040
# 13514-2  0.015385  0.009452  0.011962  0.011412  0.011782  0.008683  0.008333
# 13514-3  0.026699  0.020000  0.022727  0.022222  0.020000  0.019718  0.017928
# 53211-1  0.023641  0.014210  0.022222  0.017735  0.015428  0.018031  0.015595
# 53211-2  0.023923  0.016158  0.017897  0.020661  0.022760  0.022440  0.023810
# 53211-3  0.021429  0.014311  0.017857  0.020633  0.019830  0.018131  0.015717
#
#                 9        10        23  ...        34   10713-1   10713-2  \
# 14       0.367958  0.364103  0.172340  ...  0.151993  0.034803  0.030162
# 15       0.378012  0.378498  0.235060  ...  0.213206  0.029982  0.031915
# 16       0.358108  0.368159  0.199787  ...  0.178333  0.037281  0.032895
# 29       0.310096  0.311688  0.291058  ...  0.278195  0.029851  0.028533
# 30       0.328358  0.315217  0.279155  ...  0.277989  0.032213  0.032303
# 31       0.321078  0.314593  0.274296  ...  0.283650  0.033195  0.030429
# 8        0.520211  0.506803  0.206897  ...  0.195300  0.021033  0.025048
# 9        1.000000  0.538593  0.223014  ...  0.197421  0.036122  0.034286
# 10       0.538593  1.000000  0.217131  ...  0.214343  0.032847  0.034862
# 23       0.223014  0.217131  1.000000  ...  0.336531  0.034483  0.029656
# 24       0.217520  0.221359  0.683190  ...  0.350146  0.031891  0.030787
# 25       0.217565  0.210732  0.619497  ...  0.350554  0.033721  0.032596
# 38       0.186064  0.202144  0.366885  ...  0.559971  0.023529  0.022708
# 39       0.175544  0.197587  0.355301  ...  0.567315  0.019802  0.018993
# 40       0.193949  0.204633  0.360584  ...  0.566327  0.021997  0.022034
# 17       0.352843  0.345219  0.200000  ...  0.193440  0.039130  0.037037
# 18       0.355556  0.379661  0.194444  ...  0.167221  0.035874  0.043084
# 19       0.275335  0.283582  0.131129  ...  0.132092  0.040248  0.040498
# 26       0.275379  0.313679  0.287920  ...  0.305982  0.032520  0.022880
# 27       0.300552  0.299349  0.297064  ...  0.317847  0.029197  0.020556
# 28       0.331361  0.332558  0.325411  ...  0.299625  0.035202  0.024580
# 20       0.307018  0.307167  0.169399  ...  0.164089  0.050761  0.053708
# 21       0.287037  0.299456  0.144781  ...  0.141732  0.055072  0.052326
# 22       0.273063  0.283394  0.152100  ...  0.140351  0.037572  0.034783
# 35       0.182037  0.204674  0.350601  ...  0.528980  0.023277  0.022401
# 36       0.181054  0.205385  0.360727  ...  0.538901  0.022727  0.019328
# 37       0.181960  0.203906  0.373790  ...  0.561584  0.022356  0.020636
# 32       0.195688  0.209091  0.340668  ...  0.614477  0.023963  0.024007
# 33       0.197127  0.210987  0.325345  ...  0.664038  0.025439  0.023684
# 34       0.197421  0.214343  0.336531  ...  1.000000  0.023936  0.025801
# 10713-1  0.036122  0.032847  0.034483  ...  0.023936  1.000000  0.558824
# 10713-2  0.034286  0.034862  0.029656  ...  0.025801  0.558824  1.000000
# 10713-3  0.035185  0.043165  0.043684  ...  0.034513  0.540541  0.602837
# 13514-1  0.013807  0.026871  0.014510  ...  0.019039  0.345588  0.330882
# 13514-2  0.012270  0.017751  0.011097  ...  0.009132  0.291339  0.317073
# 13514-3  0.017544  0.024528  0.015588  ...  0.016158  0.404412  0.400000
# 53211-1  0.025048  0.035581  0.020238  ...  0.013310  0.488889  0.530769
# 53211-2  0.037402  0.032015  0.024038  ...  0.016995  0.410072  0.395683
# 53211-3  0.025243  0.026168  0.024010  ...  0.015165  0.459259  0.423358
#
#           10713-3   13514-1   13514-2   13514-3   53211-1   53211-2   53211-3
# 14       0.033708  0.017157  0.015385  0.026699  0.023641  0.023923  0.021429
# 15       0.036395  0.012821  0.009452  0.020000  0.014210  0.016158  0.014311
# 16       0.040598  0.018433  0.011962  0.022727  0.022222  0.017897  0.017857
# 29       0.036193  0.019608  0.011412  0.022222  0.017735  0.020661  0.020633
# 30       0.038728  0.012912  0.011782  0.020000  0.015428  0.022760  0.019830
# 31       0.036785  0.017045  0.008683  0.019718  0.018031  0.022440  0.018131
# 8        0.028143  0.010040  0.008333  0.017928  0.015595  0.023810  0.015717
# 9        0.035185  0.013807  0.012270  0.017544  0.025048  0.037402  0.025243
# 10       0.043165  0.026871  0.017751  0.024528  0.035581  0.032015  0.026168
# 23       0.043684  0.014510  0.011097  0.015588  0.020238  0.024038  0.024010
# 24       0.043084  0.015081  0.009434  0.013777  0.018244  0.025404  0.023015
# 25       0.047564  0.017794  0.009627  0.016432  0.017422  0.023502  0.022274
# 38       0.029240  0.018884  0.008636  0.011854  0.010059  0.012658  0.011794
# 39       0.027961  0.014310  0.009362  0.012521  0.009909  0.013311  0.014143
# 40       0.027754  0.017286  0.008711  0.011956  0.013571  0.015358  0.014480
# 17       0.051282  0.025229  0.019048  0.031746  0.031042  0.029083  0.024444
# 18       0.041575  0.021327  0.014778  0.023310  0.032184  0.025404  0.027714
# 19       0.057402  0.030405  0.025090  0.022876  0.035256  0.029126  0.025723
# 26       0.036048  0.022378  0.012802  0.019310  0.014905  0.021978  0.016371
# 27       0.033654  0.016209  0.011436  0.017305  0.012151  0.019704  0.017178
# 28       0.039897  0.020053  0.010870  0.017150  0.014286  0.021053  0.018349
# 20       0.049020  0.024064  0.022472  0.037135  0.033505  0.033943  0.036554
# 21       0.055866  0.018349  0.016181  0.030211  0.035398  0.032836  0.035821
# 22       0.038997  0.031447  0.026578  0.043478  0.035928  0.033333  0.036364
# 35       0.032114  0.014599  0.006446  0.009919  0.017102  0.019022  0.017164
# 36       0.029313  0.010239  0.006914  0.010169  0.013491  0.016129  0.017842
# 37       0.030848  0.015789  0.007965  0.013032  0.015544  0.018261  0.015598
# 32       0.034007  0.018868  0.006641  0.013035  0.011982  0.016744  0.018622
# 33       0.033188  0.018800  0.007201  0.012367  0.013146  0.015887  0.014978
# 34       0.034513  0.019039  0.009132  0.016158  0.013310  0.016995  0.015165
# 10713-1  0.540541  0.345588  0.291339  0.404412  0.488889  0.410072  0.459259
# 10713-2  0.602837  0.330882  0.317073  0.400000  0.530769  0.395683  0.423358
# 10713-3  1.000000  0.349315  0.299270  0.375839  0.462585  0.381579  0.397351
# 13514-1  0.349315  1.000000  0.430108  0.428571  0.393443  0.309524  0.317460
# 13514-2  0.299270  0.430108  1.000000  0.438776  0.398148  0.327273  0.348624
# 13514-3  0.375839  0.428571  0.438776  1.000000  0.483333  0.441667  0.474576
# 53211-1  0.462585  0.393443  0.398148  0.483333  1.000000  0.619469  0.586207
# 53211-2  0.381579  0.309524  0.327273  0.441667  0.619469  1.000000  0.584071
# 53211-3  0.397351  0.317460  0.348624  0.474576  0.586207  0.584071  1.000000
#
# [39 rows x 39 columns]
#
# Label similarity, counts of common peaks
#      CAN   CS  LAB    PN   REG  RIP    RL  ROT    RU   TRI  CFN  CHT   SB
# CAN  625  443  403   343   385  352   454  300   372   395   41   23   20
# CS   443  953  458   527   638  375   697  306   631   649   57   34   35
# LAB  403  458  670   365   421  356   470  289   414   428   44   25   33
# PN   343  527  365  1024   786  307   575  240   776   748   62   28   40
# REG  385  638  421   786  1360  340   706  268  1135  1125   64   37   40
# RIP  352  375  356   307   340  558   390  293   340   348   45   27   27
# RL   454  697  470   575   706  390  1027  314   707   712   57   34   33
# ROT  300  306  289   240   268  293   314  449   274   290   42   28   27
# RU   372  631  414   776  1135  340   707  274  1350  1107   60   35   41
# TRI  395  649  428   748  1125  348   712  290  1107  1343   61   39   39
# CFN   41   57   44    62    64   45    57   42    60    61  161   82   87
# CHT   23   34   25    28    37   27    34   28    35    39   82  117   76
# SB    20   35   33    40    40   27    33   27    41    39   87   76  129
#
# Label similarity, Jaccard indexes
#           CAN        CS       LAB        PN       REG       RIP        RL  \
# CAN  1.000000  0.390308  0.451794  0.262634  0.240625  0.423586  0.378965
# CS   0.390308  1.000000  0.393133  0.363448  0.380896  0.330106  0.543258
# LAB  0.451794  0.393133  1.000000  0.274643  0.261653  0.408257  0.383048
# PN   0.262634  0.363448  0.274643  1.000000  0.491865  0.240784  0.389566
# REG  0.240625  0.380896  0.261653  0.491865  1.000000  0.215463  0.419988
# RIP  0.423586  0.330106  0.408257  0.240784  0.215463  1.000000  0.326360
# RL   0.378965  0.543258  0.383048  0.389566  0.419988  0.326360  1.000000
# ROT  0.387597  0.279197  0.348193  0.194647  0.173913  0.410364  0.270224
# RU   0.232065  0.377392  0.257783  0.485607  0.720635  0.216837  0.423353
# TRI  0.251113  0.394050  0.270032  0.462014  0.712928  0.224082  0.429433
# CFN  0.055034  0.053926  0.055909  0.055209  0.043926  0.066766  0.050398
# CHT  0.031989  0.032819  0.032808  0.025157  0.025694  0.041667  0.030631
# SB   0.027248  0.033429  0.043081  0.035939  0.027605  0.040909  0.029386
#
#           ROT        RU       TRI       CFN       CHT        SB
# CAN  0.387597  0.232065  0.251113  0.055034  0.031989  0.027248
# CS   0.279197  0.377392  0.394050  0.053926  0.032819  0.033429
# LAB  0.348193  0.257783  0.270032  0.055909  0.032808  0.043081
# PN   0.194647  0.485607  0.462014  0.055209  0.025157  0.035939
# REG  0.173913  0.720635  0.712928  0.043926  0.025694  0.027605
# RIP  0.410364  0.216837  0.224082  0.066766  0.041667  0.040909
# RL   0.270224  0.423353  0.429433  0.050398  0.030631  0.029386
# ROT  1.000000  0.179672  0.193076  0.073944  0.052045  0.049002
# RU   0.179672  1.000000  0.697982  0.041351  0.024441  0.028512
# TRI  0.193076  0.697982  1.000000  0.042273  0.027445  0.027216
# CFN  0.073944  0.041351  0.042273  1.000000  0.418367  0.428571
# CHT  0.052045  0.024441  0.027445  0.418367  1.000000  0.447059
# SB   0.049002  0.028512  0.027216  0.428571  0.447059  1.000000

# %%
print(sim_neg)
# Out:
# Sample similarity, counts of common peaks
#           14   15   16   29   30   31    8    9   10   23  ...   34  10713-1  \
# 14       350  236  276  195  191  178  171  185  186   73  ...  157        5
# 15       236  277  188  135  128  119  153  164  167   26  ...  160        7
# 16       276  188  321  183  180  167  182  200  195   86  ...  156        5
# 29       195  135  183  503  470  437  137  144  143  124  ...  257       16
# 30       191  128  180  470  526  446  139  147  143  128  ...  274       25
# 31       178  119  167  437  446  479  123  128  128  130  ...  228       24
# 8        171  153  182  137  139  123  353  311  316   51  ...  141        4
# 9        185  164  200  144  147  128  311  365  325   57  ...  148        5
# 10       186  167  195  143  143  128  316  325  372   57  ...  151        4
# 23        73   26   86  124  128  130   51   57   57  202  ...   22       13
# 24        87   36  101  136  141  142   66   70   70  189  ...   32       13
# 25        89   35  101  142  146  149   62   68   68  190  ...   35       10
# 38       135  130  128  284  304  268  125  129  123   38  ...  320       20
# 39       120  115  110  211  227  200  111  113  112   39  ...  289       20
# 40       148  142  138  218  228  205  133  134  139   42  ...  311       22
# 17       196  184  175  117  118  101  161  178  174   30  ...  152        3
# 18       165  156  137  127  127  115  154  154  156   33  ...  123        4
# 19       156  140  134  122  121  113  151  161  153   37  ...  114        3
# 26       121  104  110  331  351  317  172  161  169   84  ...  239       16
# 27       116   99  108  268  277  273  113  120  114   54  ...  216       17
# 28       112   95  102  305  308  302  168  155  166   84  ...  191       15
# 20       189  156  135  137  139  126  147  158  155   35  ...  117        5
# 21       147  117  107   98  100   96  114  125  120   38  ...   88        4
# 22       153  123  119  109  112  106  123  137  131   39  ...   96        4
# 35       135  138  133  157  163  144  207  199  210   24  ...  260       20
# 36       133  134  131  189  195  164  119  126  124   24  ...  296       20
# 37       144  149  147  189  200  166  215  207  217   26  ...  320       21
# 32       114  111  108  164  168  157  101  101  105   30  ...  271       22
# 33       147  154  147  172  194  146  214  206  221   20  ...  310       12
# 34       157  160  156  257  274  228  141  148  151   22  ...  485       21
# 10713-1    5    7    5   16   25   24    4    5    4   13  ...   21       77
# 10713-2   10   13    8   28   34   38    8   10    8   16  ...   29       56
# 10713-3   11   13   10   27   33   35    7    9    9   22  ...   27       73
# 13514-1   36   15   33   40   46   46    5    6    4   35  ...   31       63
# 13514-2   23   13   23   35   41   41    9   10    9   31  ...   29       56
# 13514-3   44   13   41   49   55   57    9   10    8   48  ...   30       62
# 53211-1   11   13   11   29   33   37    7    9    7   21  ...   37       61
# 53211-2    8    9    9   19   27   24    7    9    7   18  ...   31       59
# 53211-3   36   13   36   57   64   62   12   15   14   49  ...   35       54
#
#          10713-2  10713-3  13514-1  13514-2  13514-3  53211-1  53211-2  \
# 14            10       11       36       23       44       11        8
# 15            13       13       15       13       13       13        9
# 16             8       10       33       23       41       11        9
# 29            28       27       40       35       49       29       19
# 30            34       33       46       41       55       33       27
# 31            38       35       46       41       57       37       24
# 8              8        7        5        9        9        7        7
# 9             10        9        6       10       10        9        9
# 10             8        9        4        9        8        7        7
# 23            16       22       35       31       48       21       18
# 24            17       23       32       27       47       21       18
# 25            16       20       32       28       45       17       15
# 38            31       30       30       31       31       34       26
# 39            28       27       30       30       29       32       25
# 40            32       30       29       31       29       33       26
# 17             8        4        8        8        9        5        3
# 18             9        6        8       10       12        6        4
# 19             7        4        5        6        7        4        3
# 26            26       27       23       29       25       25       21
# 27            28       23       28       30       26       24       20
# 28            25       24       24       29       25       22       17
# 20             8        6        6       11       11        8        8
# 21             8        5        6       12        9        6        7
# 22             8        5        6       12       10        6        7
# 35            26       25       33       29       30       31       26
# 36            26       25       29       29       28       31       24
# 37            28       30       33       35       34       34       31
# 32            28       27       26       26       23       34       30
# 33            14       20       22       23       25       26       17
# 34            29       27       31       29       30       37       31
# 10713-1       56       73       63       56       62       61       59
# 10713-2      103       79       72       72       71       70       61
# 10713-3       79      116       88       78       88       86       75
# 13514-1       72       88      143      111      123       91       80
# 13514-2       72       78      111      130      110       81       75
# 13514-3       71       88      123      110      154       93       79
# 53211-1       70       86       91       81       93      125       91
# 53211-2       61       75       80       75       79       91      105
# 53211-3       68       76      100       85      104       94       89
#
#          53211-3
# 14            36
# 15            13
# 16            36
# 29            57
# 30            64
# 31            62
# 8             12
# 9             15
# 10            14
# 23            49
# 24            49
# 25            46
# 38            31
# 39            30
# 40            28
# 17             5
# 18             9
# 19             8
# 26            36
# 27            27
# 28            30
# 20            12
# 21            10
# 22             9
# 35            38
# 36            34
# 37            40
# 32            34
# 33            26
# 34            35
# 10713-1       54
# 10713-2       68
# 10713-3       76
# 13514-1      100
# 13514-2       85
# 13514-3      104
# 53211-1       94
# 53211-2       89
# 53211-3      155
#
# [39 rows x 39 columns]
#
# Sample similarity, Jaccard indexes
#                14        15        16        29        30        31         8  \
# 14       1.000000  0.603581  0.698734  0.296353  0.278832  0.273425  0.321429
# 15       0.603581  1.000000  0.458537  0.209302  0.189630  0.186813  0.320755
# 16       0.698734  0.458537  1.000000  0.285491  0.269865  0.263823  0.369919
# 29       0.296353  0.209302  0.285491  1.000000  0.840787  0.801835  0.190542
# 30       0.278832  0.189630  0.269865  0.840787  1.000000  0.797853  0.187838
# 31       0.273425  0.186813  0.263823  0.801835  0.797853  1.000000  0.173484
# 8        0.321429  0.320755  0.369919  0.190542  0.187838  0.173484  1.000000
# 9        0.349057  0.343096  0.411523  0.198895  0.197581  0.178771  0.764128
# 10       0.347015  0.346473  0.391566  0.195355  0.189404  0.177040  0.772616
# 23       0.152401  0.057395  0.196796  0.213425  0.213333  0.235935  0.101190
# 24       0.177189  0.076759  0.225446  0.228571  0.230016  0.251327  0.128155
# 25       0.182377  0.074627  0.225951  0.241497  0.240527  0.267504  0.119691
# 38       0.204545  0.219595  0.200627  0.427711  0.455772  0.408537  0.185736
# 39       0.158730  0.167151  0.149254  0.257946  0.275152  0.248447  0.144531
# 40       0.197333  0.207906  0.188782  0.261705  0.269504  0.249392  0.173177
# 17       0.445455  0.485488  0.405093  0.174107  0.170029  0.152108  0.336820
# 18       0.364238  0.401028  0.303097  0.197205  0.190405  0.181962  0.329764
# 19       0.345133  0.354430  0.301124  0.190923  0.182504  0.181090  0.328261
# 26       0.167127  0.155689  0.155807  0.496252  0.523881  0.482496  0.254438
# 27       0.190789  0.179348  0.183986  0.440066  0.444623  0.470690  0.184039
# 28       0.162084  0.149606  0.151786  0.468510  0.459016  0.479365  0.263323
# 20       0.446809  0.407311  0.301339  0.218153  0.214176  0.204878  0.314103
# 21       0.352518  0.312834  0.250000  0.158320  0.156250  0.160804  0.251656
# 22       0.358314  0.320312  0.275463  0.174679  0.173913  0.175788  0.267391
# 35       0.171320  0.193820  0.174770  0.170838  0.174145  0.158590  0.287900
# 36       0.180217  0.201807  0.184248  0.226347  0.228873  0.196172  0.157616
# 37       0.171225  0.195282  0.181706  0.199157  0.208117  0.175105  0.278137
# 32       0.167647  0.181967  0.164384  0.209451  0.209476  0.204961  0.145115
# 33       0.186312  0.217207  0.193421  0.187568  0.211329  0.158868  0.295172
# 34       0.231563  0.265781  0.240000  0.351573  0.371777  0.309783  0.202296
# 10713-1  0.011848  0.020173  0.012723  0.028369  0.043253  0.045113  0.009390
# 10713-2  0.022573  0.035422  0.019231  0.048443  0.057143  0.069853  0.017857
# 10713-3  0.024176  0.034211  0.023419  0.045608  0.054187  0.062500  0.015152
# 13514-1  0.078775  0.037037  0.076566  0.066007  0.073836  0.079861  0.010183
# 13514-2  0.050328  0.032995  0.053738  0.058528  0.066667  0.072183  0.018987
# 13514-3  0.095652  0.031100  0.094470  0.080592  0.088000  0.098958  0.018072
# 53211-1  0.023707  0.033419  0.025287  0.048414  0.053398  0.065256  0.014862
# 53211-2  0.017897  0.024129  0.021583  0.032258  0.044702  0.042857  0.015521
# 53211-3  0.076759  0.031026  0.081818  0.094842  0.103728  0.108392  0.024194
#
#                 9        10        23  ...        34   10713-1   10713-2  \
# 14       0.349057  0.347015  0.152401  ...  0.231563  0.011848  0.022573
# 15       0.343096  0.346473  0.057395  ...  0.265781  0.020173  0.035422
# 16       0.411523  0.391566  0.196796  ...  0.240000  0.012723  0.019231
# 29       0.198895  0.195355  0.213425  ...  0.351573  0.028369  0.048443
# 30       0.197581  0.189404  0.213333  ...  0.371777  0.043253  0.057143
# 31       0.178771  0.177040  0.235935  ...  0.309783  0.045113  0.069853
# 8        0.764128  0.772616  0.101190  ...  0.202296  0.009390  0.017857
# 9        1.000000  0.788835  0.111765  ...  0.210826  0.011442  0.021834
# 10       0.788835  1.000000  0.110251  ...  0.213881  0.008989  0.017131
# 23       0.111765  0.110251  1.000000  ...  0.033083  0.048872  0.055363
# 24       0.133843  0.132075  0.784232  ...  0.046990  0.044521  0.054140
# 25       0.129771  0.128060  0.794979  ...  0.051699  0.034014  0.050955
# 38       0.189427  0.177233  0.062397  ...  0.524590  0.039841  0.059961
# 39       0.145244  0.142494  0.056604  ...  0.400277  0.034305  0.046589
# 40       0.172015  0.177977  0.059322  ...  0.430748  0.036484  0.051696
# 17       0.376321  0.359504  0.065502  ...  0.245557  0.008333  0.020997
# 18       0.321503  0.322314  0.075515  ...  0.195238  0.011730  0.024862
# 19       0.348485  0.320755  0.087470  ...  0.181240  0.009036  0.019774
# 26       0.230329  0.242120  0.137031  ...  0.322537  0.028777  0.045455
# 27       0.193861  0.180380  0.103448  ...  0.335925  0.039171  0.062361
# 28       0.233786  0.251897  0.147110  ...  0.255689  0.029126  0.047081
# 20       0.336887  0.323591  0.081585  ...  0.185714  0.014970  0.022409
# 21       0.275330  0.257511  0.100529  ...  0.144026  0.013937  0.025890
# 22       0.299127  0.278132  0.099237  ...  0.155089  0.013201  0.024615
# 35       0.269283  0.285714  0.031957  ...  0.325815  0.031746  0.040000
# 36       0.165789  0.161248  0.034335  ...  0.416901  0.034602  0.043478
# 37       0.261034  0.274684  0.032059  ...  0.400000  0.030391  0.039437
# 32       0.142655  0.147679  0.048701  ...  0.411854  0.044088  0.053950
# 33       0.276510  0.299864  0.026042  ...  0.407359  0.018433  0.020741
# 34       0.210826  0.213881  0.033083  ...  1.000000  0.038817  0.051878
# 10713-1  0.011442  0.008989  0.048872  ...  0.038817  1.000000  0.451613
# 10713-2  0.021834  0.017131  0.055363  ...  0.051878  0.451613  1.000000
# 10713-3  0.019068  0.018789  0.074324  ...  0.047038  0.608333  0.564286
# 13514-1  0.011952  0.007828  0.112903  ...  0.051926  0.401274  0.413793
# 13514-2  0.020619  0.018256  0.102990  ...  0.049488  0.370861  0.447205
# 13514-3  0.019646  0.015444  0.155844  ...  0.049261  0.366864  0.381720
# 53211-1  0.018711  0.014286  0.068627  ...  0.064572  0.432624  0.443038
# 53211-2  0.019523  0.014894  0.062284  ...  0.055456  0.479675  0.414966
# 53211-3  0.029703  0.027290  0.159091  ...  0.057851  0.303371  0.357895
#
#           10713-3   13514-1   13514-2   13514-3   53211-1   53211-2   53211-3
# 14       0.024176  0.078775  0.050328  0.095652  0.023707  0.017897  0.076759
# 15       0.034211  0.037037  0.032995  0.031100  0.033419  0.024129  0.031026
# 16       0.023419  0.076566  0.053738  0.094470  0.025287  0.021583  0.081818
# 29       0.045608  0.066007  0.058528  0.080592  0.048414  0.032258  0.094842
# 30       0.054187  0.073836  0.066667  0.088000  0.053398  0.044702  0.103728
# 31       0.062500  0.079861  0.072183  0.098958  0.065256  0.042857  0.108392
# 8        0.015152  0.010183  0.018987  0.018072  0.014862  0.015521  0.024194
# 9        0.019068  0.011952  0.020619  0.019646  0.018711  0.019523  0.029703
# 10       0.018789  0.007828  0.018256  0.015444  0.014286  0.014894  0.027290
# 23       0.074324  0.112903  0.102990  0.155844  0.068627  0.062284  0.159091
# 24       0.071651  0.094395  0.081571  0.140299  0.063253  0.057143  0.146707
# 25       0.061920  0.094675  0.085106  0.133929  0.050746  0.047319  0.136905
# 38       0.056497  0.053763  0.056985  0.054577  0.063433  0.049618  0.054482
# 39       0.043902  0.046948  0.047923  0.044547  0.051696  0.041254  0.046083
# 40       0.047319  0.043807  0.047913  0.043091  0.051562  0.041467  0.041481
# 17       0.010050  0.019002  0.019608  0.020882  0.012315  0.007732  0.011468
# 18       0.015873  0.019851  0.025773  0.029268  0.015504  0.010840  0.021739
# 19       0.010811  0.012626  0.015707  0.017284  0.010554  0.008333  0.019753
# 26       0.046233  0.037398  0.048658  0.040064  0.042017  0.036269  0.058632
# 27       0.049251  0.057260  0.063291  0.051793  0.050526  0.043573  0.053785
# 28       0.044037  0.041958  0.052347  0.042955  0.039568  0.031423  0.051903
# 20       0.016129  0.015038  0.028871  0.027160  0.021108  0.022284  0.029630
# 21       0.015385  0.017094  0.036145  0.025070  0.018018  0.022436  0.027855
# 22       0.014663  0.016349  0.034483  0.026738  0.017192  0.021341  0.023936
# 35       0.037651  0.048316  0.043027  0.043042  0.046477  0.039877  0.055072
# 36       0.040850  0.045669  0.046624  0.043277  0.050407  0.039867  0.052960
# 37       0.041609  0.044295  0.047945  0.045033  0.046832  0.043724  0.053333
# 32       0.050657  0.046346  0.047445  0.040000  0.063551  0.057803  0.060177
# 33       0.029326  0.031117  0.033189  0.034965  0.037956  0.025223  0.036364
# 34       0.047038  0.051926  0.049488  0.049261  0.064572  0.055456  0.057851
# 10713-1  0.608333  0.401274  0.370861  0.366864  0.432624  0.479675  0.303371
# 10713-2  0.564286  0.413793  0.447205  0.381720  0.443038  0.414966  0.357895
# 10713-3  1.000000  0.514620  0.464286  0.483516  0.554839  0.513699  0.389744
# 13514-1  0.514620  1.000000  0.685185  0.706897  0.514124  0.476190  0.505051
# 13514-2  0.464286  0.685185  1.000000  0.632184  0.465517  0.468750  0.425000
# 13514-3  0.483516  0.706897  0.632184  1.000000  0.500000  0.438889  0.507317
# 53211-1  0.554839  0.514124  0.465517  0.500000  1.000000  0.654676  0.505376
# 53211-2  0.513699  0.476190  0.468750  0.438889  0.654676  1.000000  0.520468
# 53211-3  0.389744  0.505051  0.425000  0.507317  0.505376  0.520468  1.000000
#
# [39 rows x 39 columns]
#
# Label similarity, counts of common peaks
#      CAN   CS  LAB   PN  REG  RIP   RL  ROT   RU  TRI  CFN  CHT   SB
# CAN  424  227  253  115  183  277  162  210  181  206   26   61   51
# CS   227  576  171  170  355  169  435  152  258  332   51   72   78
# LAB  253  171  429   83  164  253  212  193  246  271   13   13   16
# PN   115  170   83  255   69   62  125   59   49   62   31   58   56
# REG  183  355  164   69  680  188  355  127  490  564   45   45   50
# RIP  277  169  253   62  188  379  174  228  183  198   13   16   11
# RL   162  435  212  125  355  174  605  149  321  396   41   44   55
# ROT  210  152  193   59  127  228  149  288  116  134   12   16   13
# RU   181  258  246   49  490  183  321  116  702  623   44   50   57
# TRI  206  332  271   62  564  198  396  134  623  788   56   56   73
# CFN   26   51   13   31   45   13   41   12   44   56  142  108  106
# CHT   61   72   13   58   45   16   44   16   50   56  108  184  135
# SB    51   78   16   56   50   11   55   13   57   73  106  135  190
#
# Label similarity, Jaccard indexes
#           CAN        CS       LAB        PN       REG       RIP        RL  \
# CAN  1.000000  0.293661  0.421667  0.203901  0.198697  0.526616  0.186851
# CS   0.293661  1.000000  0.205036  0.257186  0.394007  0.215013  0.583110
# LAB  0.421667  0.205036  1.000000  0.138103  0.173545  0.455856  0.257908
# PN   0.203901  0.257186  0.138103  1.000000  0.079677  0.108392  0.170068
# REG  0.198697  0.394007  0.173545  0.079677  1.000000  0.215844  0.381720
# RIP  0.526616  0.215013  0.455856  0.108392  0.215844  1.000000  0.214815
# RL   0.186851  0.583110  0.257908  0.170068  0.381720  0.214815  1.000000
# ROT  0.418327  0.213483  0.368321  0.121901  0.151011  0.519362  0.200269
# RU   0.191534  0.252941  0.277966  0.053965  0.549327  0.203786  0.325558
# TRI  0.204771  0.321705  0.286469  0.063201  0.623894  0.204334  0.397192
# CFN  0.048148  0.076462  0.023297  0.084699  0.057915  0.025591  0.058074
# CHT  0.111517  0.104651  0.021667  0.152231  0.054945  0.029250  0.059060
# SB   0.090586  0.113372  0.026534  0.143959  0.060976  0.019713  0.074324
#
#           ROT        RU       TRI       CFN       CHT        SB
# CAN  0.418327  0.191534  0.204771  0.048148  0.111517  0.090586
# CS   0.213483  0.252941  0.321705  0.076462  0.104651  0.113372
# LAB  0.368321  0.277966  0.286469  0.023297  0.021667  0.026534
# PN   0.121901  0.053965  0.063201  0.084699  0.152231  0.143959
# REG  0.151011  0.549327  0.623894  0.057915  0.054945  0.060976
# RIP  0.519362  0.203786  0.204334  0.025591  0.029250  0.019713
# RL   0.200269  0.325558  0.397192  0.058074  0.059060  0.074324
# ROT  1.000000  0.132723  0.142251  0.028708  0.035088  0.027957
# RU   0.132723  1.000000  0.718570  0.055000  0.059809  0.068263
# TRI  0.142251  0.718570  1.000000  0.064073  0.061135  0.080663
# CFN  0.028708  0.055000  0.064073  1.000000  0.495413  0.469027
# CHT  0.035088  0.059809  0.061135  0.495413  1.000000  0.564854
# SB   0.027957  0.068263  0.080663  0.469027  0.564854  1.000000

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib import cm
import seaborn as sns
import pandas as pd

# %%
dfpos = pd.DataFrame(sim_pos.sample_similarity_jaccard,
                     columns=sim_pos.sample_names,
                     index=sim_pos.sample_names)

dfneg = pd.DataFrame(sim_neg.sample_similarity_jaccard,
                     columns=sim_neg.sample_names,
                     index=sim_neg.sample_names)

# %%
f, ax = plt.subplots(figsize=(12, 9))

print('Sample similarity, positive mode')
hm = sns.heatmap(dfpos, annot=False, ax=ax, cmap = sns.cm.rocket_r)
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.show()
# Out:
# Sample similarity, positive mode

# %%
f, ax = plt.subplots(figsize=(12, 9))

print('Sample similarity, negative mode')
hm = sns.heatmap(dfneg, annot=False, ax=ax, cmap = sns.cm.rocket_r)
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.show()
# Out:
# Sample similarity, negative mode

# %%
dfpos = pd.DataFrame(sim_pos.label_similarity_jaccard,
                     columns=sim_pos.unique_labels,
                     index=sim_pos.unique_labels)

dfneg = pd.DataFrame(sim_neg.label_similarity_jaccard,
                     columns=sim_neg.unique_labels,
                     index=sim_neg.unique_labels)

# %%
f, ax = plt.subplots(figsize=(12, 9))

print('Label similarity, positive mode')
hm = sns.heatmap(dfpos, annot=True, ax=ax, cmap = sns.cm.rocket_r)
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.show()
# Out:
# Label similarity, positive mode

# %%
f, ax = plt.subplots(figsize=(12, 9))

print('Label similarity, negative mode')
hm = sns.heatmap(dfneg, annot=True, ax=ax, cmap = sns.cm.rocket_r)
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.show()
# Out:
# Label similarity, negative mode

# %% [markdown]
# #### Doing... Experiments with scipy functions...

# %%
import scipy.spatial.distance as dist
import scipy.cluster.hierarchy as hier

# %%
def df_to_bool(df):
    "Transforms data into 'binary' matrices."
    df = df.copy()
    df[df.notnull()] = 1
    df[df.isnull()] = 0
    return df
aligned_01 = df_to_bool(aligned_all_neg.data)
# confirm it is 0's and 1's
#aligned_01

# %%
jdist = dist.pdist(aligned_01.T, metric='jaccard')
print(dist.squareform(jdist))
print('------------------------------------')
sim = mz_similarity(aligned_all_neg)
jsim = sim.sample_similarity_jaccard
jdist = 1 - jsim
print(jdist)
# Out:
# [[0.         0.39641944 0.30126582 ... 0.9762931  0.98210291 0.92324094]
#  [0.39641944 0.         0.54146341 ... 0.96658098 0.97587131 0.96897375]
#  [0.30126582 0.54146341 0.         ... 0.97471264 0.97841727 0.91818182]
#  ...
#  [0.9762931  0.96658098 0.97471264 ... 0.         0.34532374 0.49462366]
#  [0.98210291 0.97587131 0.97841727 ... 0.34532374 0.         0.47953216]
#  [0.92324094 0.96897375 0.91818182 ... 0.49462366 0.47953216 0.        ]]
# ------------------------------------
# [[0.         0.39641944 0.30126582 ... 0.9762931  0.98210291 0.92324094]
#  [0.39641944 0.         0.54146341 ... 0.96658098 0.97587131 0.96897375]
#  [0.30126582 0.54146341 0.         ... 0.97471264 0.97841727 0.91818182]
#  ...
#  [0.9762931  0.96658098 0.97471264 ... 0.         0.34532374 0.49462366]
#  [0.98210291 0.97587131 0.97841727 ... 0.34532374 0.         0.47953216]
#  [0.92324094 0.96897375 0.91818182 ... 0.49462366 0.47953216 0.        ]]

# %% [markdown]
# ## Wrapping up in a function...

# %%
def clustermap_peak_list(aligned):
    aligned_01 = aligned.data.copy()
    aligned_01[aligned_01.notnull()] = 1
    aligned_01[aligned_01.isnull()] = 0
    
    ulabels = aligned.unique_labels()
    n = len(ulabels)
    
    p = sns.color_palette() + sns.color_palette("Set1", n_colors=n-10, desat=.5)
    sample_to_labels = pd.Series(aligned.labels, index=aligned.sample_names)
    label_colors = pd.Series(p, index=ulabels)
    sample_colors = sample_to_labels.map(label_colors)
    
    g = sns.clustermap(aligned_01, metric="jaccard", figsize=(15, 20), 
                       row_cluster=False,
                       col_colors=sample_colors,
                       yticklabels=False)
    # fix bug in seaborn, error in clustermap if cbar == False
    ax=g.cax; aax=ax.clear(); aax = ax.axis('off'); 

    # draw legend
    lpatches = [mpatches.Patch(color=c, label=lbl) for (lbl, c) in label_colors.iteritems()]
    leg = plt.legend(handles=lpatches, fontsize=20)
    return g

# %%
print('Sample HC, NEGATIVE mode')
g = clustermap_peak_list(aligned_all_neg)
g.savefig('sampleHC_negative.pdf')
# Out:
# Sample HC, NEGATIVE mode

# %%
print('Sample HC, POSITIVE mode')
g = clustermap_peak_list(aligned_all_pos)
g.savefig('sampleHC_positive.pdf')
# Out:
# Sample HC, POSITIVE mode

# %%
print('Cultivar dendogram, Jaccard distance, NEGATIVE MODE')
jdist = dist.squareform(1 - sim_neg.label_similarity_jaccard)
Z = hier.linkage(jdist, method='average')

fig = plt.figure(figsize=(16,7))
dn = hier.dendrogram(Z, labels=sim_neg.unique_labels,
                     leaf_font_size=20,
                     above_threshold_color='b')
fig.savefig('dendo_cultivars_jaccard_negative.pdf')
# Out:
# Cultivar dendogram, Jaccard distance, NEGATIVE MODE

# %%
print(hier.cophenet(Z,jdist)[0])
# Out:
# 0.9692511986886333

# %%
print('Cultivar dendogram, Jaccard distance, POSITIVE MODE')
jdist = dist.squareform(1 - sim_pos.label_similarity_jaccard)
Z = hier.linkage(jdist, method='average')

fig = plt.figure(figsize=(16,7))
dn = hier.dendrogram(Z, labels=sim_pos.unique_labels,
                     leaf_font_size=20,
                     above_threshold_color='b')
fig.savefig('dendo_cultivars_jaccard_positive.pdf')
# Out:
# Cultivar dendogram, Jaccard distance, POSITIVE MODE

# %%
print(hier.cophenet(Z,jdist)[0])
# Out:
# 0.9789972624962274

# %% [markdown]
# ### Other Binary Similarity Analysis Methods

# %%
aligned_neg = df_to_bool(aligned_all_neg.data)
aligned_pos = df_to_bool(aligned_all_pos.data)

# %% [markdown]
# Creating the colours label for all dendrograms (negative and positive have the same labels):

# %%
label_colors = {}
colours = cm.get_cmap('nipy_spectral', 13)
col_lbl = colours(range(13))
for i in range(len(col_lbl)):
    label_colors[aligned_all_neg.labels[3*i]] = col_lbl[i]

# %%
#Apply one of the following:
#dice, hamming, jaccard, rogerstanimoto, sokalmichener, sokalsneath, yule
#kulsinski, rusellrao

print('Cultivar dendogram, Binary methods, NEGATIVE MODE, Alignment: 1-6')
Zdice_neg = hier.linkage(aligned_neg.T, metric = 'dice', method='average')

fig = plt.figure(figsize=(16,7))
dn = hier.dendrogram(Zdice_neg, labels=aligned_all_neg.labels,
                     leaf_font_size=15,
                     above_threshold_color='b')
#Coloring labels
ax = plt.gca()
ax.set_ylabel('Distance (UA)')
xlbls = ax.get_xmajorticklabels()
for lbl in xlbls:
    lbl.set_color(label_colors[lbl.get_text()])
# Out:
# Cultivar dendogram, Binary methods, NEGATIVE MODE, Alignment: 1-6

# %%
print('Cultivar dendogram, Binary methods, POSITIVE MODE, Alignment: 1-6')
Zdice_pos = hier.linkage(aligned_pos.T, metric = 'dice', method='average')

fig = plt.figure(figsize=(16,7))
dn = hier.dendrogram(Zdice_pos, labels=aligned_all_pos.labels,
                     leaf_font_size=15,
                     above_threshold_color='b')
#Coloring labels
ax = plt.gca()
ax.set_ylabel('Distance (UA)')
xlbls = ax.get_xmajorticklabels()
for lbl in xlbls:
    lbl.set_color(label_colors[lbl.get_text()])
# Out:
# Cultivar dendogram, Binary methods, POSITIVE MODE, Alignment: 1-6

# %% [markdown]
# ### Non-binary Similarity Analysis
#
# All samples need to have missing value imputation (removing features is optional) with the function NaN_Imputation of scaling.py (replace missing features with half of the minimum intensity of the full dataset).
#
# After that, the rest of the data processing can vary where 3 different processing emthods were applied in different combinations:
#
# ##### Normalization by a references feature (Norm_feat from scaling.py) - N;
# ##### Glog transformation/ log2 transformation (glog from scaling.py) - G;
# ##### Pareto Scaling (ParetoScal from scaling.py) - P.
# Three combinations were used and compared: 1) Only Pareto Scaling (P), Normalization by a reference feature and Pareto Scaling (NP) and Normalization by a reference feature, glog transformation and Pareto Scaling (NGP).

# %%
import scaling as sca
import numpy as np

# %% [markdown]
# #### Negative Mode - Alignment: 1-6
#
# 3 types of processing:
#
# Euc_P_neg - Missing Value Imputation and Pareto Scaling.
#
# Euc_NP_neg - Missing Value Imputation, Normalization by reference feature and Pareto Scaling.
#
# Euc_NGP_neg - Missing Value Imputation, Normalization by reference feature, glog transformation and Pareto Scaling.

# %%
#Euc_P_neg
Imputated_neg = sca.NaN_Imputation(aligned_all_neg, 0)
Euc_P_neg = sca.ParetoScal(Imputated_neg)

# %%
#Measure Euclidean distances
dist_euc_P_neg = dist.pdist(Euc_P_neg.data.T, metric = 'euclidean')

#Constructing Dendrogram
print('Cultivar dendogram, Euclidean distance, NEGATIVE MODE, Alignment: 1-6, NaN Imputation and Pareto Scaling')
Z_euc_P_neg = hier.linkage(dist_euc_P_neg, method='average') #ward, average, centroid, single, complete, weighted, median
fig = plt.figure(figsize=(16,7))
dn = hier.dendrogram(Z_euc_P_neg, labels=Euc_P_neg.labels,
                     leaf_font_size=15,
                     above_threshold_color='b')
#Coloring labels
ax = plt.gca()
ax.set_ylabel('Distance (UA)')
xlbls = ax.get_xmajorticklabels()
for lbl in xlbls:
    lbl.set_color(label_colors[lbl.get_text()])
# Out:
# Cultivar dendogram, Euclidean distance, NEGATIVE MODE, Alignment: 1-6, NaN Imputation and Pareto Scaling

# %%
#Cophenetic Correlation Coefficient (see how the clustering - from hier.linkage - preserves the original distances)
print(hier.cophenet(Z_euc_P_neg,dist_euc_P_neg)[0]) #method average seems to lead to higher coefficients
# Out:
# 0.9368743510481776

# %%
#Euc_NP_neg
#Theoretical mass for negative mode Leucine Enkephalin - 554.2615.
RefEst_Neg = sca.search_for_ref_feat(aligned_all_neg, 554.2615) #see if the function gives the reference feature
print(RefEst_Neg) #It did!
# Out:
# (554.26202, 0.0005200000000513683)

# %%
Norm_neg = sca.Norm_Feat(Imputated_neg, 554.26202)
Euc_NP_neg = sca.ParetoScal(Norm_neg)

# %%
#Measure Euclidean distances
dist_euc_NP_neg = dist.pdist(Euc_NP_neg.data.T, metric = 'euclidean')

#Constructing Dendrogram
print('Cultivar dendogram, Euclidean distance, NEGATIVE MODE, Alignment: 1-6, NaN Imputation, Normalized and Pareto Scaling')
Z_euc_NP_neg = hier.linkage(dist_euc_NP_neg, method='average') #ward, average, centroid, single, complete, weighted, median
fig = plt.figure(figsize=(16,7))
dn = hier.dendrogram(Z_euc_NP_neg, labels=Euc_NP_neg.labels,
                     leaf_font_size=15,
                     above_threshold_color='b')
#Coloring labels
ax = plt.gca()
ax.set_ylabel('Distance (UA)')
xlbls = ax.get_xmajorticklabels()
for lbl in xlbls:
    lbl.set_color(label_colors[lbl.get_text()])
# Out:
# Cultivar dendogram, Euclidean distance, NEGATIVE MODE, Alignment: 1-6, NaN Imputation, Normalized and Pareto Scaling

# %%
print(hier.cophenet(Z_euc_NP_neg,dist_euc_NP_neg)[0])
# Out:
# 0.8687439863912411

# %%
#Euc_NGP_neg
glog_neg = sca.glog(Norm_neg, 0)
Euc_NGP_neg = sca.ParetoScal(glog_neg)

# %%
#Measure Euclidean distances
dist_euc_NGP_neg = dist.pdist(Euc_NGP_neg.data.T, metric = 'euclidean')

#Constructing Dendrogram
print('Cultivar dendogram, Euclidean distance, NEGATIVE MODE, Alignment: 1-6, NaN Imputation, Normalized, Transformed and Pareto Scaling')
Z_euc_NGP_neg = hier.linkage(dist_euc_NGP_neg, method='average') #ward, average, centroid, single, complete, weighted, median
fig = plt.figure(figsize=(16,7))
dn = hier.dendrogram(Z_euc_NGP_neg, labels=Euc_NGP_neg.labels,
                     leaf_font_size=15,
                     above_threshold_color='b')
#Coloring labels
ax = plt.gca()
ax.set_ylabel('Distance (UA)')
xlbls = ax.get_xmajorticklabels()
for lbl in xlbls:
    lbl.set_color(label_colors[lbl.get_text()])
# Out:
# Cultivar dendogram, Euclidean distance, NEGATIVE MODE, Alignment: 1-6, NaN Imputation, Normalized, Transformed and Pareto Scaling

# %%
print(hier.cophenet(Z_euc_NGP_neg,dist_euc_NGP_neg)[0])
# Out:
# 0.8897651283558525

# %% [markdown]
# #### Positive Mode - Alignment: 1-6
#
# 3 types of processing:
#
# Euc_P_pos - Missing Value Imputation and Pareto Scaling.
#
# Euc_NP_pos - Missing Value Imputation, Normalization by reference feature and Pareto Scaling.
#
# Euc_NGP_pos - Missing Value Imputation, Normalization by reference feature, glog transformation and Pareto Scaling.

# %%
#Euc_P_pos
Imputated_pos = sca.NaN_Imputation(aligned_all_pos, 0)
Euc_P_pos = sca.ParetoScal(Imputated_pos)

# %%
#Measure Euclidean distances
dist_euc_P_pos = dist.pdist(Euc_P_pos.data.T, metric = 'euclidean')

#Constructing Dendrogram
print('Cultivar dendogram, Euclidean distance, POSITIVE MODE, Alignment: 1-6, NaN Imputation and Pareto Scaling')
Z_euc_P_pos = hier.linkage(dist_euc_P_pos, method='average') #ward, average, centroid, single, complete, weighted, median
fig = plt.figure(figsize=(16,7))
dn = hier.dendrogram(Z_euc_P_pos, labels=Euc_P_pos.labels,
                     leaf_font_size=15,
                     above_threshold_color='b')
#Coloring labels
ax = plt.gca()
ax.set_ylabel('Distance (UA)')
xlbls = ax.get_xmajorticklabels()
for lbl in xlbls:
    lbl.set_color(label_colors[lbl.get_text()])
# Out:
# Cultivar dendogram, Euclidean distance, POSITIVE MODE, Alignment: 1-6, NaN Imputation and Pareto Scaling

# %%
print(hier.cophenet(Z_euc_P_pos,dist_euc_P_pos)[0])
# Out:
# 0.9781078659909838

# %%
#Euc_NP_pos
#Theoretical mass for positive mode Leucine Enkephalin - 556.2771.
RefEst_Pos = sca.search_for_ref_feat(aligned_all_pos, 556.2771)
print(RefEst_Pos)
# Out:
# (556.2765712820513, 0.0005287179486686)

# %%
Norm_pos = sca.Norm_Feat(Imputated_pos, 556.2765712820513)
Euc_NP_pos = sca.ParetoScal(Norm_pos)

# %%
#Measure Euclidean distances
dist_euc_NP_pos = dist.pdist(Euc_NP_pos.data.T, metric = 'euclidean')

#Constructing Dendrogram
print('Cultivar dendogram, Euclidean distance, POSITIVE MODE, Alignment: 1-6, NaN Imputation, Normalized and Pareto Scaling')
Z_euc_NP_pos = hier.linkage(dist_euc_NP_pos, method='average') #ward, average, centroid, single, complete, weighted, median
fig = plt.figure(figsize=(16,7))
dn = hier.dendrogram(Z_euc_NP_pos, labels=Euc_NP_pos.labels,
                     leaf_font_size=15,
                     above_threshold_color='b')
#Coloring labels
ax = plt.gca()
ax.set_ylabel('Distance (UA)')
xlbls = ax.get_xmajorticklabels()
for lbl in xlbls:
    lbl.set_color(label_colors[lbl.get_text()])
# Out:
# Cultivar dendogram, Euclidean distance, POSITIVE MODE, Alignment: 1-6, NaN Imputation, Normalized and Pareto Scaling

# %%
print(hier.cophenet(Z_euc_NP_pos,dist_euc_NP_pos)[0])
# Out:
# 0.8826739925270107

# %%
#Euc_NGP_pos
glog_pos = sca.glog(Norm_pos, 0)
Euc_NGP_pos = sca.ParetoScal(glog_pos)

# %%
#Measure Euclidean distances
dist_euc_NGP_pos = dist.pdist(Euc_NGP_pos.data.T, metric = 'euclidean')

#Constructing Dendrogram
print('Cultivar dendogram, Euclidean distance, POSITIVE MODE, Alignment: 1-6, NaN Imputation, Normalized, Transformed and Pareto Scaling')
Z_euc_NGP_pos = hier.linkage(dist_euc_NGP_pos, method='average') #ward, average, centroid, single, complete, weighted, median
fig = plt.figure(figsize=(16,7))
dn = hier.dendrogram(Z_euc_NGP_pos, labels=Euc_NGP_pos.labels,
                     leaf_font_size=15,
                     above_threshold_color='b')
#Coloring labels
ax = plt.gca()
xlbls = ax.get_xmajorticklabels()
for lbl in xlbls:
    lbl.set_color(label_colors[lbl.get_text()])
# Out:
# Cultivar dendogram, Euclidean distance, POSITIVE MODE, Alignment: 1-6, NaN Imputation, Normalized, Transformed and Pareto Scaling

# %%
print(hier.cophenet(Z_euc_NGP_pos,dist_euc_NGP_pos)[0])
# Out:
# 0.8388999998313593

# %% [markdown]
# ## 2nd Peak Alignment - 1-13
#
# #### Negative Mode - Peak alignment (only requires a feature to be present in at least 13 of the total 39 samples)
#
# Same procedure as before:
#
# 3 types of processing:
#
# Euc_P_neg2 (in script, 1_13 in figures) - Missing Value Imputation and Pareto Scaling.
#
# Euc_NP_neg2 (in script, 1_13 in figures) - Missing Value Imputation, Normalization by reference feature and Pareto Scaling.
#
# Euc_NGP_neg2 (in script, 1_13 in figures) - Missing Value Imputation, Normalization by reference feature, glog transformation and Pareto Scaling.

# %%
aligned_all_pos2 = read_aligned_spectra('aligned_1ppm_min1-13_1ppm_positive.csv', labels=True, sep=',')
aligned_all_neg2 = read_aligned_spectra('aligned_1ppm_min1-13_1ppm_negative.csv', labels=True, sep=',')

# %%
#Euc_P_neg2
Imputated_neg2 = sca.NaN_Imputation(aligned_all_neg2, 0)
Euc_P_neg2 = sca.ParetoScal(Imputated_neg2)

# %%
#Measure Euclidean distances
dist_euc_P_neg2 = dist.pdist(Euc_P_neg2.data.T, metric = 'euclidean')

#Constructing Dendrogram
print('Cultivar dendogram, Euclidean distance, NEGATIVE MODE, Peak Alignment: 1-13, NaN Imputation and Pareto Scaling')
Z_euc_P_neg2 = hier.linkage(dist_euc_P_neg2, method='average') #ward, average, centroid, single, complete, weighted, median
fig = plt.figure(figsize=(16,7))
dn = hier.dendrogram(Z_euc_P_neg2, labels=Euc_P_neg2.labels,
                     leaf_font_size=15,
                     above_threshold_color='b')
#Coloring labels
ax = plt.gca()
ax.set_ylabel('Distance (UA)')
xlbls = ax.get_xmajorticklabels()
for lbl in xlbls:
    lbl.set_color(label_colors[lbl.get_text()])
# Out:
# Cultivar dendogram, Euclidean distance, NEGATIVE MODE, Peak Alignment: 1-13, NaN Imputation and Pareto Scaling

# %%
print(hier.cophenet(Z_euc_P_neg2,dist_euc_P_neg2)[0])
# Out:
# 0.8575812513519465

# %%
#Euc_NP_neg2
#Theoretical mass for negative mode Leucine Enkephalin - 554.2615.
RefEst_Pos = sca.search_for_ref_feat(aligned_all_neg2, 554.2615)
print(RefEst_Pos) #Same result as previous alignment.
Norm_neg2 = sca.Norm_Feat(Imputated_neg2, 554.26202)
Euc_NP_neg2 = sca.ParetoScal(Norm_neg2)
# Out:
# (554.26202, 0.0005200000000513683)

# %%
#Measure Euclidean distances
dist_euc_NP_neg2 = dist.pdist(Euc_NP_neg2.data.T, metric = 'euclidean')

#Constructing Dendrogram
print('Cultivar dendogram, Euclidean distance, NEGATIVE MODE, Peak Alignment: 1-13, NaN Imputation, Normalized and Pareto Scaling')
Z_euc_NP_neg2 = hier.linkage(dist_euc_NP_neg2, method='average') #ward, average, centroid, single, complete, weighted, median
fig = plt.figure(figsize=(16,7))
dn = hier.dendrogram(Z_euc_NP_neg2, labels=Euc_NP_neg2.labels,
                     leaf_font_size=15,
                     above_threshold_color='b')
#Coloring labels
ax = plt.gca()
ax.set_ylabel('Distance (UA)')
xlbls = ax.get_xmajorticklabels()
for lbl in xlbls:
    lbl.set_color(label_colors[lbl.get_text()])
# Out:
# Cultivar dendogram, Euclidean distance, NEGATIVE MODE, Peak Alignment: 1-13, NaN Imputation, Normalized and Pareto Scaling

# %%
print(hier.cophenet(Z_euc_NP_neg2,dist_euc_NP_neg2)[0])
# Out:
# 0.9341887591326181

# %%
#Euc_NGP_neg2
glog_neg2 = sca.glog(Norm_neg2, 0)
Euc_NGP_neg2 = sca.ParetoScal(glog_neg2)

# %%
#Measure Euclidean distances
dist_euc_NGP_neg2 = dist.pdist(Euc_NGP_neg2.data.T, metric = 'euclidean')

#Constructing Dendrogram
print('Cultivar dendogram, Euclidean distance, NEGATIVE MODE, Peak Alignment: 1-13, NaN Imputation, Normalized, Transformed and Pareto Scaling')
Z_euc_NGP_neg2 = hier.linkage(dist_euc_NGP_neg2, method='average') #ward, average, centroid, single, complete, weighted, median
fig = plt.figure(figsize=(16,7))
dn = hier.dendrogram(Z_euc_NGP_neg2, labels=Euc_NGP_neg2.labels,
                     leaf_font_size=15,
                     above_threshold_color='b')
#Coloring labels
ax = plt.gca()
ax.set_ylabel('Distance (UA)')
xlbls = ax.get_xmajorticklabels()
for lbl in xlbls:
    lbl.set_color(label_colors[lbl.get_text()])
# Out:
# Cultivar dendogram, Euclidean distance, NEGATIVE MODE, Peak Alignment: 1-13, NaN Imputation, Normalized, Transformed and Pareto Scaling

# %%
print(hier.cophenet(Z_euc_NGP_neg2,dist_euc_NGP_neg2)[0]) #method average seems to lead to higher coefficients
# Out:
# 0.871088705335994

# %% [markdown]
# #### Positive Mode - Peak alignment (only requires a feature to be present in at least 13 of the total 39 samples)
#
# Same procedure as before:
#
# 3 types of processing:
#
# Euc_P_pos2 (in script, 1_13 in figures) - Missing Value Imputation and Pareto Scaling.
#
# Euc_NP_pos2 (in script, 1_13 in figures) - Missing Value Imputation, Normalization by reference feature and Pareto Scaling.
#
# Euc_NGP_pos2 (in script, 1_13 in figures) - Missing Value Imputation, Normalization by reference feature, glog transformation and Pareto Scaling

# %%
#Euc_P_pos2
Imputated_pos2 = sca.NaN_Imputation(aligned_all_pos2, 0)
Euc_P_pos2 = sca.ParetoScal(Imputated_pos2)

# %%
#Measure Euclidean distances
dist_euc_P_pos2 = dist.pdist(Euc_P_pos2.data.T, metric = 'euclidean')

#Constructing Dendrogram
print('Cultivar dendogram, Euclidean distance, POSITIVE MODE, Peak Alignment: 1-13, NaN Imputation and Pareto Scaling')
Z_euc_P_pos2 = hier.linkage(dist_euc_P_pos2, method='average') #ward, average, centroid, single, complete, weighted, median
fig = plt.figure(figsize=(16,7))
dn = hier.dendrogram(Z_euc_P_pos2, labels=Euc_P_pos2.labels,
                     leaf_font_size=15,
                     above_threshold_color='b')
#Coloring labels
ax = plt.gca()
ax.set_ylabel('Distance (UA)')
xlbls = ax.get_xmajorticklabels()
for lbl in xlbls:
    lbl.set_color(label_colors[lbl.get_text()])
# Out:
# Cultivar dendogram, Euclidean distance, POSITIVE MODE, Peak Alignment: 1-13, NaN Imputation and Pareto Scaling

# %%
print(hier.cophenet(Z_euc_P_pos2,dist_euc_P_pos2)[0])
# Out:
# 0.9705145065702774

# %%
#Euc_NP_pos2
#Theoretical mass for positive mode Leucine Enkephalin - 556.2771.
RefEst_Pos = sca.search_for_ref_feat(aligned_all_pos2, 556.2771)
print(RefEst_Pos) #Same result as previous alignment.
Norm_pos2 = sca.Norm_Feat(Imputated_pos2, 556.27657128205135)
Euc_NP_pos2 = sca.ParetoScal(Norm_pos2)
# Out:
# (556.2765712820513, 0.0005287179486686)

# %%
#Measure Euclidean distances
dist_euc_NP_pos2 = dist.pdist(Euc_NP_pos2.data.T, metric = 'euclidean')

#Constructing Dendrogram
print('Cultivar dendogram, Euclidean distance, POSITIVE MODE, Peak Alignment: 1-13, NaN Imputation, Normalized and Pareto Scaling')
Z_euc_NP_pos2 = hier.linkage(dist_euc_NP_pos2, method='average') #ward, average, centroid, single, complete, weighted, median
fig = plt.figure(figsize=(16,7))
dn = hier.dendrogram(Z_euc_NP_pos2, labels=Euc_NP_pos2.labels,
                     leaf_font_size=15,
                     above_threshold_color='b')
#Coloring labels
ax = plt.gca()
ax.set_ylabel('Distance (UA)')
xlbls = ax.get_xmajorticklabels()
for lbl in xlbls:
    lbl.set_color(label_colors[lbl.get_text()])
# Out:
# Cultivar dendogram, Euclidean distance, POSITIVE MODE, Peak Alignment: 1-13, NaN Imputation, Normalized and Pareto Scaling

# %%
print(hier.cophenet(Z_euc_NP_pos2,dist_euc_NP_pos2)[0])
# Out:
# 0.8728223886096169

# %%
#Euc_NGP_pos
glog_pos2 = sca.glog(Norm_pos2, 0)
Euc_NGP_pos2 = sca.ParetoScal(glog_pos2)

# %%
#Measure Euclidean distances
dist_euc_NGP_pos2 = dist.pdist(Euc_NGP_pos2.data.T, metric = 'euclidean')

#Constructing Dendrogram
print('Cultivar dendogram, Euclidean distance, POSITIVE MODE, Peak Alignment: 1-13, NaN Imputation, Normalized, Transformed and Pareto Scaling')
Z_euc_NGP_pos2 = hier.linkage(dist_euc_NGP_pos2, method='average') #ward, average, centroid, single, complete, weighted, median
fig = plt.figure(figsize=(16,7))
dn = hier.dendrogram(Z_euc_NGP_pos2, labels=Euc_NGP_pos2.labels,
                     leaf_font_size=15,
                     above_threshold_color='b')
#Coloring labels
ax = plt.gca()
ax.set_ylabel('Distance (UA)')
xlbls = ax.get_xmajorticklabels()
for lbl in xlbls:
    lbl.set_color(label_colors[lbl.get_text()])
# Out:
# Cultivar dendogram, Euclidean distance, POSITIVE MODE, Peak Alignment: 1-13, NaN Imputation, Normalized, Transformed and Pareto Scaling

# %%
print(hier.cophenet(Z_euc_NGP_pos2,dist_euc_NGP_pos2)[0])
# Out:
# 0.9054051721958662

# %% [markdown]
# ### Binary distances example for peak_alignment 2: 1-13

# %%
aligned_neg2 = df_to_bool(aligned_all_neg2.data)
aligned_pos2 = df_to_bool(aligned_all_pos2.data)

# %%
#Apply one of the following:
#dice, hamming, jaccard, rogerstanimoto, sokalmichener, sokalsneath, yule
#kulsinski, rusellrao

print('Cultivar dendogram, Binary methods, NEGATIVE MODE, Peak Alignment: 1-13')
Zdice_neg2 = hier.linkage(aligned_neg2.T, metric = 'dice', method='average')

fig = plt.figure(figsize=(16,7))
dn = hier.dendrogram(Zdice_neg2, labels=aligned_all_neg2.labels,
                     leaf_font_size=15,
                     above_threshold_color='b')
#Coloring labels
ax = plt.gca()
ax.set_ylabel('Distance (UA)')
xlbls = ax.get_xmajorticklabels()
for lbl in xlbls:
    lbl.set_color(label_colors[lbl.get_text()])
# Out:
# Cultivar dendogram, Binary methods, NEGATIVE MODE, Peak Alignment: 1-13

# %%
print('Cultivar dendogram, Binary methods, POSITIVE MODE, Peak Alignment: 1-13')
Zdice_pos2 = hier.linkage(aligned_pos2.T, metric = 'dice', method='average')

fig = plt.figure(figsize=(16,7))
dn = hier.dendrogram(Zdice_pos2, labels=aligned_all_pos2.labels,
                     leaf_font_size=15,
                     above_threshold_color='b')
#Coloring labels
ax = plt.gca()
ax.set_ylabel('Distance (UA)')
xlbls = ax.get_xmajorticklabels()
for lbl in xlbls:
    lbl.set_color(label_colors[lbl.get_text()])
# Out:
# Cultivar dendogram, Binary methods, POSITIVE MODE, Peak Alignment: 1-13

# %% [markdown]
# ### Comparing Dendrograms
#
# #### Two methods so far: Baker's Gamma Correlation and Cophenetic Correlation Coefficient
#
# #### Examples of procedure with these methods

# %%
import numpy as np
import scipy.stats as stats
import multianalysis as ma

# %% [markdown]
# #### Baker's method
#
# Use of the mergerank function from multianalysis to create a 'rank' of the iteration number two samples were linked to the same cluster.

# %%
euclidean = (Z_euc_P_neg, Z_euc_NP_neg, Z_euc_NGP_neg, Z_euc_P_pos, Z_euc_NP_pos, Z_euc_NGP_pos,
            Z_euc_P_neg2, Z_euc_NP_neg2, Z_euc_NGP_neg2, Z_euc_P_pos2, Z_euc_NP_pos2, Z_euc_NGP_pos2)
dist_euclidean = (dist_euc_P_neg, dist_euc_NP_neg, dist_euc_NGP_neg, dist_euc_P_pos, dist_euc_NP_pos, dist_euc_NGP_pos,
                 dist_euc_P_neg2, dist_euc_NP_neg2, dist_euc_NGP_neg2, dist_euc_P_pos2, dist_euc_NP_pos2, dist_euc_NGP_pos2)

K_euc = []
S_euc = []
Coph_euc = []

for i in range(len(euclidean)):
    K_euc.append(ma.mergerank(euclidean[i])) #Mergerank
    S_euc.append(K_euc[i][K_euc[i]!=0]) #Both reshape to a 1D array (needed for spearman correlation) and take out 0's 
    Coph_euc.append(hier.cophenet(euclidean[i], dist_euclidean[i])) #Matrix of Cophenetic distances

# %% [markdown]
# #### Examples
#
# According to Original Paper (Stability of Two Hierarchical Grouping Techniques Case 1: Sensitivity to Data Errors)

# %%
print('Pair of samples      \tKendall Correlation \tp-value')
print('Euc_P_neg-Euc_NP_neg\t', stats.kendalltau(S_euc[0],S_euc[1])[0], '\t', stats.kendalltau(S_euc[0],S_euc[1])[1])
print('Euc_P_neg-Euc_NGP_neg\t', stats.kendalltau(S_euc[0],S_euc[2])[0], '\t', stats.kendalltau(S_euc[0],S_euc[2])[1])
# Out:
# Pair of samples      	Kendall Correlation 	p-value
# Euc_P_neg-Euc_NP_neg	 0.003309790648165927 	 0.8661938836924192
# Euc_P_neg-Euc_NGP_neg	 0.1793832447874397 	 1.912762735703408e-19

# %% [markdown]
# According to the explanation given in the R package dendextend

# %%
print('Pair of samples      \tSpearman Correlation \tp-value')
print('Euc_P_neg-Euc_NP_neg\t', stats.spearmanr(S_euc[0],S_euc[1])[0], '\t', stats.spearmanr(S_euc[0],S_euc[1])[1])
print('Euc_P_neg-Euc_NGP_neg\t', stats.spearmanr(S_euc[0],S_euc[2])[0], '\t', stats.spearmanr(S_euc[0],S_euc[2])[1])
# Out:
# Pair of samples      	Spearman Correlation 	p-value
# Euc_P_neg-Euc_NP_neg	 -0.02405398470126864 	 0.354782396826829
# Euc_P_neg-Euc_NGP_neg	 0.2029665275136164 	 3.0410003780838496e-15

# %% [markdown]
# #### Cophenetic Correlation Coefficient

# %%
#Acho que se pode aplicar logo a função np.corrcoef visto os elementos que vêm da função cophenet estão sempre na mesma ordem 
#uns em relação aos outros.

# %%
print('Pair of samples      \tPearson Correlation \tp-value')
print('Euc_P_neg-Euc_NP_neg\t', stats.pearsonr(Coph_euc[0][1],Coph_euc[1][1])[0], '\t', stats.pearsonr(Coph_euc[0][1],Coph_euc[1][1])[1])
print('Euc_P_neg-Euc_NGP_neg\t', stats.pearsonr(Coph_euc[0][1],Coph_euc[2][1])[0], '\t', stats.pearsonr(Coph_euc[0][1],Coph_euc[2][1])[1])
# Out:
# Pair of samples      	Pearson Correlation 	p-value
# Euc_P_neg-Euc_NP_neg	 0.025976755436031854 	 0.48015902421950646
# Euc_P_neg-Euc_NGP_neg	 0.3321692616201329 	 1.5151144183973443e-20

# %% [markdown]
# ### Comparison of dendrograms made with all binary metrics and euclidean distances
#
# #### Correlations between all pairs using all 3 methods

# %%
#9 binary methods accepted in pdist (scipy.spatial.distances.pdist)
binary = ('dice', 'hamming', 'jaccard', 'rogerstanimoto', 'sokalmichener', 'sokalsneath', 'yule', 'kulsinski', 'russellrao')

# %%
#Application of all "single" steps needed presented in the examples above with every distance metric.
#Negative mode
Z_neg = []
K_neg = []
S_neg = []
Coph_neg = []

for i in range(len(binary)):
    Z_neg.append(hier.linkage(aligned_neg.T, metric = binary[i], method='average')) #Z
    K_neg.append(ma.mergerank(Z_neg[i])) #Mergerank
    S_neg.append(K_neg[i][K_neg[i]!=0]) #Eliminating 0's
    Coph_neg.append(hier.cophenet(Z_neg[i], dist.pdist(aligned_neg.T, metric = binary[i]))) #Cophenetic

# %%
#Positive Mode
Z_pos = []
K_pos = []
S_pos = []
Coph_pos = []

for i in range(len(binary)):
    Z_pos.append(hier.linkage(aligned_pos.T, metric = binary[i], method='average')) #Z
    K_pos.append(ma.mergerank(Z_pos[i])) #Mergerank
    S_pos.append(K_pos[i][K_pos[i]!=0]) #Eliminating 0's
    Coph_pos.append(hier.cophenet(Z_pos[i], dist.pdist(aligned_pos.T, metric = binary[i]))) #Cophenetic

# %%
#Creation of a list with all the "rank" values (in order) for the different metrics: 
#Negative Euclideans, Positive Euclideans, Negative Binaries, Positive Binaries
S = []
S.extend(S_euc)
S.extend(S_neg)
S.extend(S_pos)
#Creation of a list with all the returns from the function cophenetic for the different metrics: 
#Negative Euclideans, Positive Euclideans, Negative Binaries, Positive Binaries
Coph = []
Coph.extend(Coph_euc)
Coph.extend(Coph_neg)
Coph.extend(Coph_pos)

# %% [markdown]
# Creation of all dataframes needed to store all correlation coeficients and respective p-values fot all three methods

# %%
#Column names and row names for the dataframes
colnames = ['euc_P_neg1_6', 'euc_NP_neg1_6', 'euc_NGP_neg1_6', 'euc_P_pos1_6', 'euc_NP_pos1_6', 'euc_NGP_pos1_6',
            'euc_P_neg1_13', 'euc_NP_neg1_13', 'euc_NGP_neg1_13', 'euc_P_pos1_13', 'euc_NP_pos1_13', 'euc_NGP_pos1_13',
            'dice_neg1_6', 'hamming_neg1_6', 'jaccard_neg1_6', 'rogerstanimoto_neg1_6', 'sokalmichener_neg1_6', 
            'sokalsneath_neg1_6','yule_neg1_6', 'kulsinski_neg1_6', 'russellrao_neg1_6','dice_pos1_6', 'hamming_pos1_6', 
            'jaccard_pos1_6', 'rogerstanimoto_pos1_6', 'sokalmichener_pos1_6', 'sokalsneath_pos1_6', 'yule_pos1_6', 
            'kulsinski_pos1_6', 'russellrao_pos1_6']

# %%
df_K = pd.DataFrame(np.zeros((len(S),len(S))), columns = colnames, index = colnames) #K - Kendall (Baker)
df_S = pd.DataFrame(np.zeros((len(S),len(S))), columns = colnames, index = colnames) #S - Spearman (Baker)
df_C = pd.DataFrame(np.zeros((len(S),len(S))), columns = colnames, index = colnames) #C - Cophenetic Correlation
df_K_p = pd.DataFrame(np.zeros((len(S),len(S))), columns = colnames, index = colnames) #p-values of K method
df_S_p = pd.DataFrame(np.zeros((len(S),len(S))), columns = colnames, index = colnames) #p-values of S method
df_C_p = pd.DataFrame(np.zeros((len(S),len(S))), columns = colnames, index = colnames) #p-values of C method

# %%
#Calculation of correlation coefficient for each method
for i in range(len(S)):
    for j in range(len(S)):
        df_K.iloc[i,j] = stats.kendalltau(S[i],S[j])[0] #Correlation coefficient
        df_S.iloc[i,j] = stats.spearmanr(S[i],S[j])[0] #Correlation coefficient
        df_C.iloc[i,j] = stats.pearsonr(Coph[i][1],Coph[j][1])[0] #Correlation coefficient
        df_K_p.iloc[i,j] = stats.kendalltau(S[i],S[j])[1] #p-value
        df_S_p.iloc[i,j] = stats.spearmanr(S[i],S[j])[1] #p-value
        df_C_p.iloc[i,j] = stats.pearsonr(Coph[i][1],Coph[j][1])[1] #p-value
        
#Inserting blank lines in the DataFrame for better presentation and separation
line = pd.DataFrame(np.empty((1,len(S)))* np.nan, columns = colnames, index=[''])
lineV = pd.concat([line.iloc[:,:12], pd.DataFrame(np.empty((1,1))* np.nan, columns =[''], index = ['']), line.iloc[:,12:]], axis = 1)
df_KI = pd.concat([df_K.iloc[:12], line, df_K.iloc[12:]])
df_KI = pd.concat([df_KI.iloc[:,:12], lineV.T, df_KI.iloc[:,12:]], axis = 1)
df_SI = pd.concat([df_S.iloc[:12], line, df_S.iloc[12:]])
df_SI = pd.concat([df_SI.iloc[:,:12], lineV.T, df_SI.iloc[:,12:]], axis = 1)
df_CI = pd.concat([df_C.iloc[:12], line, df_C.iloc[12:]])
df_CI = pd.concat([df_CI.iloc[:,:12], lineV.T, df_CI.iloc[:,12:]], axis = 1)

# %% [markdown]
# ### Heatmaps of the correlation coeficients for the 3 methods

# %%
f, ax = plt.subplots(figsize=(20, 15))

print('Baker (Kendall) Correlation Coefficient Heatmap (between dendrograms made with different distance metrics)')
print('Name Convention: First 12: Euclidean_DataProcessing_Mode; Last 18: DistanceMetric_Mode')
print('Euc1_6 - Peak alignment requiring that a feature appears in at least 6 samples of all samples.')
print('Euc1_13 - Peak alignment requiring that a feature appears at least in 13 samples of all samples.')
hm = sns.heatmap(df_KI, annot=True, ax=ax, cmap = sns.cm.rocket_r)
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.text(6,-0.2,'Conventional', fontsize  = 15, horizontalalignment='center')
plt.text(31.2,6,'Conventional', fontsize  = 15, rotation = 270, verticalalignment='center')
plt.text(22,-0.2,'Binaries', fontsize = 15, horizontalalignment='center')
plt.text(31.2,22,'Binaries', fontsize  = 15, rotation = 270, verticalalignment='center')
plt.show()
# Out:
# Baker (Kendall) Correlation Coefficient Heatmap (between dendrograms made with different distance metrics)
# Name Convention: First 12: Euclidean_DataProcessing_Mode; Last 18: DistanceMetric_Mode
# Euc1_6 - Peak alignment requiring that a feature appears in at least 6 samples of all samples.
# Euc1_13 - Peak alignment requiring that a feature appears at least in 13 samples of all samples.

# %%
Kendall = pd.DataFrame(np.zeros((9, 5)), index = ('dice', 'hamming', 'jaccard', 'rogerstanimoto', 'sokalmichener', 'sokalsneath', 
                                                 'yule', 'kulsinski', 'russellrao'), columns = ('neg1_6', 'pos1_6', 'neg1-13', 
                                                                                                'pos1-13', 'neg+pos'))

for j in range(5):
    for r in range(9):
        if j in [0,2]:
            Kendall.iloc[r,j] = sum(df_K.iloc[12+r,j*3:j*3+3])
        elif j in [1,3]:
            Kendall.iloc[r,j] = sum(df_K.iloc[21+r,j*3:j*3+3])
        else:
            Kendall.iloc[r,j] = sum(Kendall.iloc[r,0:4])
#print(Kendall)

# %%
for j in range(5):
    for r in range(9):
        if j in [0,2]:
            Kendall.iloc[r,j] = df_K.iloc[12+r,j*3+2]#sum(df_C.iloc[12+r,j*3+2])j*3:j*3+3])
        elif j in [1,3]:
            Kendall.iloc[r,j] = df_K.iloc[21+r,j*3+2]#sum(df_C.iloc[21+r,j*3+2])j*3:j*3+3])
        else:
            Kendall.iloc[r,j] = sum(Kendall.iloc[r,0:4])
f, ax = plt.subplots(figsize=(5, 4))
hm = sns.heatmap(Kendall, annot=True, ax=ax, cmap = sns.cm.rocket_r)
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.show()

# %%
f, ax = plt.subplots(figsize=(20, 15))

print('Baker (Spearman) Correlation Coefficient Heatmap (between dendrograms made with different distance metrics)')
print('Name Convention: First 12: Euclidean_DataProcessing_Mode; Last 18: DistanceMetric_Mode')
print('Euc1_6 - Peak alignment requiring that a feature appears in at least 6 samples of all samples.')
print('Euc1_13 - Peak alignment requiring that a feature appears at least in 13 samples of all samples.')
hm = sns.heatmap(df_SI, annot=True, ax=ax, cmap = sns.cm.rocket_r)
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.text(6,-0.2,'Conventional', fontsize  = 15, horizontalalignment='center')
plt.text(31.2,6,'Conventional', fontsize  = 15, rotation = 270, verticalalignment='center')
plt.text(22,-0.2,'Binaries', fontsize = 15, horizontalalignment='center')
plt.text(31.2,22,'Binaries', fontsize  = 15, rotation = 270, verticalalignment='center')
plt.show()
# Out:
# Baker (Spearman) Correlation Coefficient Heatmap (between dendrograms made with different distance metrics)
# Name Convention: First 12: Euclidean_DataProcessing_Mode; Last 18: DistanceMetric_Mode
# Euc1_6 - Peak alignment requiring that a feature appears in at least 6 samples of all samples.
# Euc1_13 - Peak alignment requiring that a feature appears at least in 13 samples of all samples.

# %%
f, ax = plt.subplots(figsize=(20, 15))

print('Cophenetic Correlation Coefficient Heatmap (between dendrograms made with different distance metrics)')
print('Name Convention: First 12: Euclidean_DataProcessing_Mode; Last 18: DistanceMetric_Mode')
print('Euc1_6 - Peak alignment requiring that a feature appears in at least 6 samples of all samples.')
print('Euc1_13 - Peak alignment requiring that a feature appears at least in 13 samples of all samples.')
hm = sns.heatmap(df_CI, annot=True, ax=ax, cmap = sns.cm.rocket_r)
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.text(6,-0.2,'Conventional', fontsize  = 15, horizontalalignment='center')
plt.text(31.2,6,'Conventional', fontsize  = 15, rotation = 270, verticalalignment='center')
plt.text(22,-0.2,'Binaries', fontsize = 15, horizontalalignment='center')
plt.text(31.2,22,'Binaries', fontsize  = 15, rotation = 270, verticalalignment='center')
plt.show()
# Out:
# Cophenetic Correlation Coefficient Heatmap (between dendrograms made with different distance metrics)
# Name Convention: First 12: Euclidean_DataProcessing_Mode; Last 18: DistanceMetric_Mode
# Euc1_6 - Peak alignment requiring that a feature appears in at least 6 samples of all samples.
# Euc1_13 - Peak alignment requiring that a feature appears at least in 13 samples of all samples.

# %%
Cophenetic = pd.DataFrame(np.zeros((9, 5)), index = ('dice', 'hamming', 'jaccard', 'rogerstanimoto', 'sokalmichener', 'sokalsneath', 
                                                 'yule', 'kulsinski', 'russellrao'), columns = ('neg1_6', 'pos1_6', 'neg1-13', 
                                                                                                'pos1-13','neg+pos'))

for j in range(5):
    for r in range(9):
        if j in [0,2]:
            Cophenetic.iloc[r,j] = sum(df_C.iloc[12+r,j*3:j*3+3])
        elif j in [1,3]:
            Cophenetic.iloc[r,j] = sum(df_C.iloc[21+r,j*3:j*3+3])
        else:
            Cophenetic.iloc[r,j] = sum(Cophenetic.iloc[r,0:4])
#print(Cophenetic)

# %%
for j in range(5):
    for r in range(9):
        if j in [0,2]:
            Cophenetic.iloc[r,j] = df_C.iloc[12+r,j*3+2]#sum(df_C.iloc[12+r,j*3+2])j*3:j*3+3])
        elif j in [1,3]:
            Cophenetic.iloc[r,j] = df_C.iloc[21+r,j*3+2]#sum(df_C.iloc[21+r,j*3+2])j*3:j*3+3])
        else:
            Cophenetic.iloc[r,j] = sum(Cophenetic.iloc[r,0:4])
f, ax = plt.subplots(figsize=(5, 4))
hm = sns.heatmap(Cophenetic, annot=True, ax=ax, cmap = sns.cm.rocket_r)
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.show()

# %% [markdown]
# ### Hierarchical clustering of the correlation coeficients of dendrograms made with different distance metrics with each other

# %% [markdown]
# Colours for these labels (groups: neg_peakalignment1, pos_peakalignment1, neg_peakalignment2, pos_peakalignment2, neg_binary, pos_binary

# %%
label_colors2 = {}
colours2 = cm.get_cmap('nipy_spectral', 6)
col_lbl2 = colours2(range(6))
for i in range(4):
    label_colors2[df_K.columns[3*i]] = col_lbl2[i]
    label_colors2[df_K.columns[3*i+1]] = col_lbl2[i]
    label_colors2[df_K.columns[3*i+2]] = col_lbl2[i]
for i in range(9):
    label_colors2[df_K.columns[12+i]] = col_lbl2[4]
    label_colors2[df_K.columns[21+i]] = col_lbl2[5]

# %%
print('Hierarchical clustering of the Baker (Kendall) Correlation Coefficients of the dendrograms made with different distance metrics')
print('Name Convention: First 12: Euclidean_DataProcessing_Mode; Last 18: DistanceMetric_Mode')
print('Euc1_6 - Peak alignment requiring that a feature appears in at least 6 samples of all samples.')
print('Euc1_13 - Peak alignment requiring that a feature appears at least in 13 samples of all samples.')
Z_K = hier.linkage(df_K, metric = 'euclidean', method = 'average')
fig = plt.figure(figsize=(16,7))
dn = hier.dendrogram(Z_K, labels=df_K.columns,
                     leaf_font_size=15,
                     above_threshold_color='b',
                     orientation = 'left')
#Coloring labels
ax = plt.gca()
ax.set_xlabel('Distance (UA)')
xlbls = ax.get_ymajorticklabels()
for lbl in xlbls:
    lbl.set_color(label_colors2[lbl.get_text()])
# Out:
# Hierarchical clustering of the Baker (Kendall) Correlation Coefficients of the dendrograms made with different distance metrics
# Name Convention: First 12: Euclidean_DataProcessing_Mode; Last 18: DistanceMetric_Mode
# Euc1_6 - Peak alignment requiring that a feature appears in at least 6 samples of all samples.
# Euc1_13 - Peak alignment requiring that a feature appears at least in 13 samples of all samples.

# %%
print('Hierarchical clustering of the Baker (Spearman) Correlation Coefficients of the dendrograms made with different distance metrics')
print('Name Convention: First 12: Euclidean_DataProcessing_Mode; Last 18: DistanceMetric_Mode')
print('Euc1_6 - Peak alignment requiring that a feature appears in at least 6 samples of all samples.')
print('Euc1_13 - Peak alignment requiring that a feature appears at least in 13 samples of all samples.')
Z_S = hier.linkage(df_S, metric = 'euclidean', method = 'average')
fig = plt.figure(figsize=(16,7))
dn = hier.dendrogram(Z_S, labels=df_S.columns,
                     leaf_font_size=15,
                     above_threshold_color='b',
                     orientation = 'left')
#Coloring labels
ax = plt.gca()
ax.set_xlabel('Distance (UA)')
xlbls = ax.get_ymajorticklabels()
for lbl in xlbls:
    lbl.set_color(label_colors2[lbl.get_text()])
# Out:
# Hierarchical clustering of the Baker (Spearman) Correlation Coefficients of the dendrograms made with different distance metrics
# Name Convention: First 12: Euclidean_DataProcessing_Mode; Last 18: DistanceMetric_Mode
# Euc1_6 - Peak alignment requiring that a feature appears in at least 6 samples of all samples.
# Euc1_13 - Peak alignment requiring that a feature appears at least in 13 samples of all samples.

# %%
print('Hierarchical clustering of the Cophenetic Correlation Coefficients of the dendrograms made with different distance metrics')
print('Name Convention: First 12: Euclidean_DataProcessing_Mode; Last 18: DistanceMetric_Mode')
print('Euc2_1 - Peak alignment requiring that a feature appears in two of the three samples of a certain variety')
print('Euc1_13 - Peak alignment requiring that a feature appears at least in 13 samples of all samples.')
Z_C = hier.linkage(df_C, metric = 'euclidean', method = 'average')
fig = plt.figure(figsize=(16,7))
dn = hier.dendrogram(Z_C, labels=df_C.columns,
                     leaf_font_size=15,
                     above_threshold_color='b',
                     orientation = 'left')
#Coloring labels
ax = plt.gca()
ax.set_xlabel('Distance (UA)')
xlbls = ax.get_ymajorticklabels()
for lbl in xlbls:
    lbl.set_color(label_colors2[lbl.get_text()])
# Out:
# Hierarchical clustering of the Cophenetic Correlation Coefficients of the dendrograms made with different distance metrics
# Name Convention: First 12: Euclidean_DataProcessing_Mode; Last 18: DistanceMetric_Mode
# Euc2_1 - Peak alignment requiring that a feature appears in two of the three samples of a certain variety
# Euc1_13 - Peak alignment requiring that a feature appears at least in 13 samples of all samples.

# %% [markdown]
# ### Distance discrimination of all methods applied (and shown in previous heatmap/dendrogram).

# %%
#Preparing Z linkage matrices
Z = []
Z.extend(euclidean)
Z.extend(Z_neg)
Z.extend(Z_pos)

# %%
disc_average = np.zeros((1,30))
disc_median = np.zeros((1,30))
disc_correct = np.zeros((1,30))
for i in range(len(Z)):
    discrim = sca.dist_discrim(aligned_all_neg, Z[i], 3, method = 'average')  #all samples have the same order
    disc_average[0,i] = discrim[0]
    disc_median[0,i] = sca.dist_discrim(aligned_all_neg, Z[i], 3, 'median')[0] #all samples have the same order
    correct = np.array(list(discrim[1].values()))
    disc_correct[0,i] = len(correct[correct>0])

disc_average = pd.DataFrame(disc_average, index = ['distances average'], columns = colnames)
disc_median = pd.DataFrame(disc_median, index = ['distances median'], columns = colnames)
disc_correct = pd.DataFrame(disc_correct, index = ['correct groupings'], columns = colnames)

#Inserting blank lines in the DataFrame for better presentation and separation
line = pd.DataFrame(np.empty((1,1))* np.nan, index = [''])
disc_average = pd.concat([disc_average.iloc[:,:12], pd.DataFrame(np.empty((1,1))* np.nan, index = [''],
                                                columns = ['distances average']).T, disc_average.iloc[:,12:]], axis = 1)
disc_median = pd.concat([disc_median.iloc[:,:12], pd.DataFrame(np.empty((1,1))* np.nan, index = [''],
                                                columns = ['distances median']).T, disc_median.iloc[:,12:]], axis = 1)
disc_correct = pd.concat([disc_correct.iloc[:,:12], pd.DataFrame(np.empty((1,1))* np.nan, index = [''],
                                                columns = ['correct groupings']).T, disc_correct.iloc[:,12:]], axis = 1)

# %%
f, ax = plt.subplots(figsize=(20, 1))
hm = sns.heatmap(disc_average, annot=True, ax=ax, cmap = sns.cm.rocket_r)
plt.text(6,-0.2,'Conventional', fontsize  = 12, horizontalalignment='center')
plt.text(22,-0.2,'Binaries', fontsize = 12, horizontalalignment='center')
plt.show()

# %%
f, ax = plt.subplots(figsize=(20, 1))
hm = sns.heatmap(disc_median, annot=True, ax=ax, cmap = sns.cm.rocket_r)

# %%
f, ax = plt.subplots(figsize=(20, 1))
hm = sns.heatmap(disc_correct, annot=True, ax=ax, cmap = sns.cm.rocket_r)

# %% [markdown]
# 1-13 binaries discrimination distance

# %%
#Negative mode
Z_neg = []
K_neg = []
S_neg = []
Coph_neg = []

for i in range(len(binary)):
    Z_neg.append(hier.linkage(aligned_neg2.T, metric = binary[i], method='average')) #Z
    K_neg.append(ma.mergerank(Z_neg[i])) #Mergerank
    S_neg.append(K_neg[i][K_neg[i]!=0]) #Eliminating 0's
    Coph_neg.append(hier.cophenet(Z_neg[i], dist.pdist(aligned_neg2.T, metric = binary[i]))) #Cophenetic

    #Positive Mode
Z_pos = []
K_pos = []
S_pos = []
Coph_pos = []

for i in range(len(binary)):
    Z_pos.append(hier.linkage(aligned_pos2.T, metric = binary[i], method='average')) #Z
    K_pos.append(ma.mergerank(Z_pos[i])) #Mergerank
    S_pos.append(K_pos[i][K_pos[i]!=0]) #Eliminating 0's
    Coph_pos.append(hier.cophenet(Z_pos[i], dist.pdist(aligned_pos2.T, metric = binary[i]))) #Cophenetic

# %%
#Preparing Z linkage matrices
euclidean = (Z_euc_P_neg, Z_euc_NP_neg, Z_euc_NGP_neg, Z_euc_P_pos, Z_euc_NP_pos, Z_euc_NGP_pos,
            Z_euc_P_neg2, Z_euc_NP_neg2, Z_euc_NGP_neg2, Z_euc_P_pos2, Z_euc_NP_pos2, Z_euc_NGP_pos2)
Z = []
Z.extend(euclidean)
Z.extend(Z_neg)
Z.extend(Z_pos)

# %%
colnames = ['euc_P_neg1_6', 'euc_NP_neg1_6', 'euc_NGP_neg1_6', 'euc_P_pos1_6', 'euc_NP_pos1_6', 'euc_NGP_pos1_6',
            'euc_P_neg1_13', 'euc_NP_neg1_13', 'euc_NGP_neg1_13', 'euc_P_pos1_13', 'euc_NP_pos1_13', 'euc_NGP_pos1_13',
            'dice_neg1_13', 'hamming_neg1_13', 'jaccard_neg1_13', 'rogerstanimoto_neg1_13', 'sokalmichener_neg1_13', 
            'sokalsneath_neg1_13','yule_neg1_13', 'kulsinski_neg1_13', 'russellrao_neg1_13', 'dice_pos1_13', 'hamming_pos1_13', 
            'jaccard_pos1_13', 'rogerstanimoto_pos1_13', 'sokalmichener_pos1_13', 'sokalsneath_pos1_13', 'yule_pos1_13', 
            'kulsinski_pos1_13', 'russellrao_pos1_13']

# %%
disc_average = np.zeros((1,30))
disc_median = np.zeros((1,30))
disc_correct = np.zeros((1,30))
for i in range(len(Z)):
    discrim = sca.dist_discrim(aligned_all_neg, Z[i], 3, method = 'average')  #all samples have the same order
    disc_average[0,i] = discrim[0]
    disc_median[0,i] = sca.dist_discrim(aligned_all_neg, Z[i], 3, 'median')[0] #all samples have the same order
    correct = np.array(list(discrim[1].values()))
    disc_correct[0,i] = len(correct[correct>0])

disc_average = pd.DataFrame(disc_average, index = ['distances average'], columns = colnames)
disc_median = pd.DataFrame(disc_median, index = ['distances median'], columns = colnames)
disc_correct = pd.DataFrame(disc_correct, index = ['correct groupings'], columns = colnames)

# %%
f, ax = plt.subplots(figsize=(20, 1))
hm = sns.heatmap(disc_average.iloc[:,6:], annot=True, ax=ax, cmap = sns.cm.rocket_r)

# %%
f, ax = plt.subplots(figsize=(20, 1))
hm = sns.heatmap(disc_median, annot=True, ax=ax, cmap = sns.cm.rocket_r)

# %%
f, ax = plt.subplots(figsize=(20, 1))
hm = sns.heatmap(disc_correct.iloc[:,6:], annot=True, ax=ax, cmap = sns.cm.rocket_r)

# %% [markdown]
# ### Extra binary measures of peak alignment 2: 1-13

# %%
sim_pos = mz_similarity(aligned_all_pos2)
sim_neg = mz_similarity(aligned_all_neg2)

# %%
dfpos = pd.DataFrame(sim_pos.sample_similarity_jaccard,
                     columns=sim_pos.sample_names,
                     index=sim_pos.sample_names)

dfneg = pd.DataFrame(sim_neg.sample_similarity_jaccard,
                     columns=sim_neg.sample_names,
                     index=sim_neg.sample_names)

# %%
f, ax = plt.subplots(figsize=(12, 9))

print('Sample similarity, positive mode, Peak Alignment: 1_13')
hm = sns.heatmap(dfpos, annot=False, ax=ax, cmap = sns.cm.rocket_r)
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.show()
# Out:
# Sample similarity, positive mode, Peak Alignment: 1_13

# %%
f, ax = plt.subplots(figsize=(12, 9))

print('Sample similarity, negative mode, Peak Alignment: 1_13')
hm = sns.heatmap(dfneg, annot=False, ax=ax, cmap = sns.cm.rocket_r)
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.show()
# Out:
# Sample similarity, negative mode, Peak Alignment: 1_13

# %%
print('Sample HC, NEGATIVE mode, Peak Alignment: 1-13')
g = clustermap_peak_list(aligned_all_neg2)
# Out:
# Sample HC, NEGATIVE mode, Peak Alignment: 1-13

# %%
print('Sample HC, POSITIVE mode, Peak Alignment: 1-13')
g = clustermap_peak_list(aligned_all_pos2)
# Out:
# Sample HC, POSITIVE mode, Peak Alignment: 1-13

# %% [markdown]
# ### K-means clustering

# %%
import sklearn.cluster as skclust

# %% [markdown]
# #### Example of what happens in a K-means clustering and how samples are separated
# Use of the module do sci-kit learn - sklearn. Cluster number equal to the amount of varieties. How well can this method separate the varieties. Default parameters except number of clusters.
#
# This example doesn't necessarily mirror the results below (for the case in example) since K-means clustering has an intrinsically random side to it and the clustering is performed again for the case example.

# %%
Kmean = skclust.KMeans(n_clusters=13)

# %%
a = Kmean.fit(Euc_NGP_neg.data.T)

# %%
dicto = {}
for i in range(len(a.labels_)):
    if a.labels_[i] in dicto:
        dicto[a.labels_[i]].append(aligned_all_neg.labels[i])
    else:
        dicto[a.labels_[i]] = [aligned_all_neg.labels[i]]
dicto
# Out:
# {8: ['CAN', 'CAN', 'CAN'],
#  7: ['CS', 'CS', 'CS'],
#  6: ['LAB', 'LAB', 'LAB'],
#  5: ['PN', 'PN', 'PN', 'SB'],
#  1: ['REG', 'TRI'],
#  11: ['REG', 'REG'],
#  4: ['RIP', 'RIP', 'RIP'],
#  2: ['RL', 'RL', 'RL'],
#  10: ['ROT', 'ROT', 'ROT'],
#  12: ['RU', 'RU'],
#  3: ['RU', 'TRI'],
#  9: ['TRI'],
#  0: ['CFN', 'CFN', 'CFN', 'CHT', 'CHT', 'CHT', 'SB', 'SB']}

# %% [markdown]
# ### K-means clustering applied to all euclidean methods and the binary matrixes built
#
# To try and get a condensed and more easily digestible version of the results, a method similar to the discrimination distance performed in the hierarchical clustering was made. The same metrics as before are used.
#
# Replicates of a variety can be together in a cluster but, if there are more samples in the same cluster, its "discrimination distance" is still zero. Therefore, this method is harsher than the original dist_discrim method. The distance is calculated as the distance between the centroid of the cluster where the samples are and the closest centroid. This distance is normalized by dividing it by the maximum distance between any 2 centroids of the clusters formed. The mean/median of the discrimination distances of all groups is then a measure of the global discrimination distance
#
# Use of the Kmeans_discrim function from multianalysis to calculate discrimination distance.

# %%
#aligned_neg2 = df_to_bool(aligned_all_neg2.data)
#aligned_pos2 = df_to_bool(aligned_all_pos2.data)

# %%
colnames2 = ['euc_P_neg1_6', 'euc_NP_neg1_6', 'euc_NGP_neg1_6', 'euc_P_pos1_6', 'euc_NP_pos1_6', 'euc_NGP_pos1_6',
             'euc_P_neg1_13', 'euc_NP_neg1_13', 'euc_NGP_neg1_13', 'euc_P_pos1_13', 'euc_NP_pos1_13', 'euc_NGP_pos1_13',
             'aligned_neg1_6', 'aligned_pos1_6','aligned_neg1_13', 'aligned_pos1_13']

# %%
euclidean = (Euc_P_neg, Euc_NP_neg, Euc_NGP_neg, Euc_P_pos, Euc_NP_pos, Euc_NGP_pos,
            Euc_P_neg2, Euc_NP_neg2, Euc_NGP_neg2, Euc_P_pos2, Euc_NP_pos2, Euc_NGP_pos2)#, 
binaries = (aligned_neg, aligned_pos, aligned_neg2, aligned_pos2)

# %%
from metabolinks import AlignedSpectra

# %%
disc_average = np.zeros((1,16))
disc_median = np.zeros((1,16))
disc_correct = np.zeros((1,16))
for i in range(len(euclidean)):
    discrim = ma.Kmeans_discrim(euclidean[i], 3, method = 'average')  #all samples have the same order
    disc_average[0,i] = discrim[0]
    disc_median[0,i] = ma.Kmeans_discrim(euclidean[i], 3, method = 'median')[0] #all samples have the same order
    correct = np.array(list(discrim[1].values()))
    disc_correct[0,i] = len(correct[correct>0])
for i in range(len(binaries)):
    discrim = ma.Kmeans_discrim(AlignedSpectra(binaries[i], labels = aligned_all_neg.labels), 3, method = 'average')
    disc_average[0,12 + i] 
    disc_average[0,12 + i] = discrim[0]
    disc_median[0,12 + i] = ma.Kmeans_discrim(AlignedSpectra(binaries[i], labels = aligned_all_neg.labels), 3, method = 'median')[0] 
    correct = np.array(list(discrim[1].values()))
    disc_correct[0,12 + i] = len(correct[correct>0])

disc_average = pd.DataFrame(disc_average, index = ['distances average'], columns = colnames2)
disc_median = pd.DataFrame(disc_median, index = ['distances median'], columns = colnames2)
disc_correct = pd.DataFrame(disc_correct, index = ['correct groupings'], columns = colnames2)

#Inserting blank lines in the DataFrame for better presentation and separation
line = pd.DataFrame(np.empty((1,1))* np.nan, index = [''])
disc_average = pd.concat([disc_average.iloc[:,:6], pd.DataFrame(np.empty((1,1))* np.nan, index = [''],
                                                columns = ['distances average']).T, disc_average.iloc[:,6:12], 
                                                pd.DataFrame(np.empty((1,1))* np.nan, index = [''], columns = 
                                                ['distances average']).T, disc_average.iloc[:,12:]], axis = 1)
disc_median = pd.concat([disc_median.iloc[:,:6], pd.DataFrame(np.empty((1,1))* np.nan, index = [''],
                                                columns = ['distances median']).T, disc_median.iloc[:,6:12], 
                                                pd.DataFrame(np.empty((1,1))* np.nan, index = [''], columns = 
                                                ['distances median']).T, disc_median.iloc[:,12:]], axis = 1)
disc_correct = pd.concat([disc_correct.iloc[:,:6], pd.DataFrame(np.empty((1,1))* np.nan, index = [''],
                                                columns = ['correct groupings']).T, disc_correct.iloc[:,6:12], 
                                                pd.DataFrame(np.empty((1,1))* np.nan, index = [''], columns = 
                                                ['correct groupings']).T, disc_correct.iloc[:,12:]], axis = 1)

# %%
f, ax = plt.subplots(figsize=(20, 1))
hm = sns.heatmap(disc_average, annot=True, ax=ax, cmap = sns.cm.rocket_r)
plt.text(3,-0.2,'1-6', fontsize  = 12, horizontalalignment='center')
plt.text(10,-0.2,'1-13', fontsize  = 12, horizontalalignment='center')
plt.text(16,-0.2,'Binaries', fontsize = 12, horizontalalignment='center')
plt.show()

# %%
f, ax = plt.subplots(figsize=(20, 1))
hm = sns.heatmap(disc_median, annot=True, ax=ax, cmap = sns.cm.rocket_r)

# %%
f, ax = plt.subplots(figsize=(20, 1))
hm = sns.heatmap(disc_correct, annot=True, ax=ax, cmap = sns.cm.rocket_r)

# %% [markdown]
# ### RandomForests Attempts - 3-fold cross-validation, n_estimators = 200
#
# This section of the notebook takes some time.

# %%
#Creation of "binary" Spectras using the binary matrices built with the function df_to_bool.
binary_neg1 = AlignedSpectra(aligned_neg, labels = aligned_all_neg.labels)
binary_neg2 = AlignedSpectra(aligned_neg2, labels = aligned_all_neg2.labels)
binary_pos1 = AlignedSpectra(aligned_pos, labels = aligned_all_pos.labels)
binary_pos2 = AlignedSpectra(aligned_pos2, labels = aligned_all_pos2.labels)

# %% [markdown]
# ### Test number of trees needed for convergence for N, NP, NGP and binary data (both alignments)
#
# Grid search of number of trees from 10 to 1000 for the random forests. See where the cross-validation score stops improving for each one.
#
# #### Takes  considerable time - Turn to code only when needed so it doesn't slow the notebook runtime more than it already is.

# %% [markdown]
# from sklearn.model_selection import GridSearchCV
# import sklearn.ensemble as skensemble
# #Vector with values for the parameter n_estimators
# values = {}
# values['n_estimators'] = range(10,750,10)
# rf = skensemble.RandomForestClassifier(n_estimators = 200)
# clf = GridSearchCV(rf, values, cv =3)

# %% [markdown]
# param = []
# test_score = []
# for i in range(len(euclidean[:6])):
#     clf.fit(euclidean[i].data.T, euclidean[6+i].labels)
#     param.append(clf.cv_results_['param_n_estimators'])
#     test_score.append(clf.cv_results_['mean_test_score'])
# for i in range(len(binaries[:2])):
#     clf.fit(binaries[i].T, Euc_P_neg.labels)
#     param.append(clf.cv_results_['param_n_estimators'])
#     test_score.append(clf.cv_results_['mean_test_score'])

# %% [markdown]
# f, ax = plt.subplots(figsize=(12,9))
# plt.plot(param[0], test_score[0])
# plt.plot(param[1], test_score[1])
# plt.plot(param[2], test_score[2])
# plt.plot(param[6], test_score[6])
# plt.ylabel('CV Mean Test Score')
# plt.xlabel('Number of Trees')
# ax.legend(('P', 'NP', 'NGP', 'Binary'))
# print('Performance based on number of trees - Alignment: 6, Negative Mode')

# %% [markdown]
# f, ax = plt.subplots(figsize=(12,9))
# plt.plot(param[3], test_score[3])
# plt.plot(param[4], test_score[4])
# plt.plot(param[5], test_score[5])
# plt.plot(param[7], test_score[7])
# plt.ylabel('CV Mean Test Score')
# plt.xlabel('Number of Trees')
# ax.legend(('P', 'NP', 'NGP', 'Binary'))
# print('Performance based on number of trees - Alignment: 6, Positive Mode')

# %% [markdown]
# param = []
# test_score = []
# for i in range(len(euclidean[6:])):
#     clf.fit(euclidean[6+i].data.T, euclidean[6+i].labels)
#     param.append(clf.cv_results_['param_n_estimators'])
#     test_score.append(clf.cv_results_['mean_test_score'])
# for i in range(len(binaries[2:])):
#     clf.fit(binaries[2+i].T, Euc_P_neg.labels)
#     param.append(clf.cv_results_['param_n_estimators'])
#     test_score.append(clf.cv_results_['mean_test_score'])

# %% [markdown]
# f, ax = plt.subplots(figsize=(12,9))
# plt.plot(param[0], test_score[0])
# plt.plot(param[1], test_score[1])
# plt.plot(param[2], test_score[2])
# plt.plot(param[6], test_score[6])
# plt.ylabel('CV Mean Test Score')
# plt.xlabel('Number of Trees')
# ax.legend(('P', 'NP', 'NGP', 'Binary'))
# print('Performance based on number of trees - Alignment: 13, Negative Mode')

# %% [markdown]
# f, ax = plt.subplots(figsize=(12,9))
# plt.plot(param[3], test_score[3])
# plt.plot(param[4], test_score[4])
# plt.plot(param[5], test_score[5])
# plt.plot(param[7], test_score[7])
# plt.ylabel('CV Mean Test Score')
# plt.xlabel('Number of Trees')
# ax.legend(('P', 'NP', 'NGP', 'Binary'))
# print('Performance based on number of trees - Alignment: 13, Positive Mode')

# %% [markdown]
# ### Performance of N, NP and NGP data treatments (alignment 1-6 and 1-13)
#
# See performance of all 3 treatments and absence of them in non-binary data to see which performs the best using method nº1 (simple application of random forests), see below.

# %%
Teste = {}
Teste_std = {}
Teste_feat = {}

# %%
N1_D = ma.simple_RF(Imputated_neg, iter_num = 100)#, n_trees = 500)
Teste['Imp_neg1_6'] = np.mean(N1_D[0])
Teste_std['Imp_neg1_6'] = np.std(N1_D[0])
Teste_feat['Imp_neg1_6'] = N1_D[1]
N1_D = ma.simple_RF(Euc_P_neg, iter_num = 100)#, n_trees = 500)
Teste['P_neg1_6'] = np.mean(N1_D[0])
Teste_std['P_neg1_6'] = np.std(N1_D[0])
Teste_feat['P_neg1_6'] = N1_D[1]
N1_D = ma.simple_RF(Euc_NP_neg, iter_num = 100)#, n_trees = 500)
Teste['NP_neg1_6'] = np.mean(N1_D[0])
Teste_std['NP_neg1_6'] = np.std(N1_D[0])
Teste_feat['NP_neg1_6'] = N1_D[1]
N1_D = ma.simple_RF(Euc_NGP_neg, iter_num = 100)#, n_trees = 500)
Teste['NGP_neg1_6'] = np.mean(N1_D[0])
Teste_std['NGP_neg1_6'] = np.std(N1_D[0])
Teste_feat['NGP_neg1_6'] = N1_D[1]

# %%
N1_D = ma.simple_RF(Imputated_pos, iter_num = 100)#, n_trees = 500)
Teste['Imp_pos1_6'] = np.mean(N1_D[0])
Teste_std['Imp_pos1_6'] = np.std(N1_D[0])
Teste_feat['Imp_pos1_6'] = N1_D[1]
N1_D = ma.simple_RF(Euc_P_pos, iter_num = 100)#, n_trees = 500)
Teste['P_pos1_6'] = np.mean(N1_D[0])
Teste_std['P_pos1_6'] = np.std(N1_D[0])
Teste_feat['P_pos1_6'] = N1_D[1]
N1_D = ma.simple_RF(Euc_NP_pos, iter_num = 100)#, n_trees = 500)
Teste['NP_pos1_6'] = np.mean(N1_D[0])
Teste_std['NP_pos1_6'] = np.std(N1_D[0])
Teste_feat['NP_pos1_6'] = N1_D[1]
N1_D = ma.simple_RF(Euc_NGP_pos, iter_num = 100)#, n_trees = 500)
Teste['NGP_pos1_6'] = np.mean(N1_D[0])
Teste_std['NGP_pos1_6'] = np.std(N1_D[0])
Teste_feat['NGP_pos1_6'] = N1_D[1]

# %%
N1_D = ma.simple_RF(Imputated_neg2, iter_num = 100)#, n_trees = 500)
Teste['Imp_neg1_13'] = np.mean(N1_D[0])
Teste_std['Imp_neg1_13'] = np.std(N1_D[0])
Teste_feat['Imp_neg1_13'] = N1_D[1]
N1_D = ma.simple_RF(Euc_P_neg2, iter_num = 100)#, n_trees = 500)
Teste['P_neg1_13'] = np.mean(N1_D[0])
Teste_std['P_neg1_13'] = np.std(N1_D[0])
Teste_feat['P_neg1_13'] = N1_D[1]
N1_D = ma.simple_RF(Euc_NP_neg2, iter_num = 100)#, n_trees = 500)
Teste['NP_neg1_13'] = np.mean(N1_D[0])
Teste_std['NP_neg1_13'] = np.std(N1_D[0])
Teste_feat['NP_neg1_13'] = N1_D[1]
N1_D = ma.simple_RF(Euc_NGP_neg2, iter_num = 100)#, n_trees = 500)
Teste['NGP_neg1_13'] = np.mean(N1_D[0])
Teste_std['NGP_neg1_13'] = np.std(N1_D[0])
Teste_feat['NGP_neg1_13'] = N1_D[1]

# %%
N1_D = ma.simple_RF(Imputated_pos2, iter_num = 100)#, n_trees = 500)
Teste['Imp_pos1_13'] = np.mean(N1_D[0])
Teste_std['Imp_pos1_13'] = np.std(N1_D[0])
Teste_feat['Imp_pos1_13'] = N1_D[1]
N1_D = ma.simple_RF(Euc_P_pos2, iter_num = 100)#, n_trees = 500)
Teste['P_pos1_13'] = np.mean(N1_D[0])
Teste_std['P_pos1_13'] = np.std(N1_D[0])
Teste_feat['P_pos1_13'] = N1_D[1]
N1_D = ma.simple_RF(Euc_NP_pos2, iter_num = 100)#, n_trees = 500)
Teste['NP_pos1_13'] = np.mean(N1_D[0])
Teste_std['NP_pos1_13'] = np.std(N1_D[0])
Teste_feat['NP_pos1_13'] = N1_D[1]
N1_D = ma.simple_RF(Euc_NGP_pos2, iter_num = 100)#, n_trees = 500)
Teste['NGP_pos1_13'] = np.mean(N1_D[0])
Teste_std['NGP_pos1_13'] = np.std(N1_D[0])
Teste_feat['NGP_pos1_13'] = N1_D[1]

# %%
Teste_H = pd.DataFrame(list(Teste.values()), index = Teste.keys()).T
#Inserting blank lines in the DataFrame for better presentation and separation
Teste_H = pd.concat([Teste_H.iloc[:,:8], pd.DataFrame(np.empty((1,1))* np.nan, index = ['']).T, Teste_H.iloc[:,8:]], axis = 1)
f, ax = plt.subplots(figsize=(20, 1))
hm = sns.heatmap(Teste_H, annot=True, ax=ax, cmap = sns.cm.rocket_r, yticklabels = ['RF_CV'])
plt.text(4,-0.2,'1-6', fontsize  = 12, horizontalalignment='center')
plt.text(13,-0.2,'1-13', fontsize  = 12, horizontalalignment='center')
plt.show()

# %%
Teste_std_H = pd.DataFrame(list(Teste_std.values()), index = Teste.keys()).T
#Inserting blank lines in the DataFrame for better presentation and separation
Teste_std_H = pd.concat([Teste_std_H.iloc[:,:8], pd.DataFrame(np.empty((1,1))* np.nan, index = ['']).T, Teste_std_H.iloc[:,8:]], 
                        axis = 1)
f, ax = plt.subplots(figsize=(20, 1))
hm = sns.heatmap(Teste_std_H, annot=True, ax=ax, cmap = sns.cm.rocket_r, yticklabels = ['RF_CV_std'])

# %% [markdown]
# Accuracy plot with errors bars corresponding to the 95% confidence interval and accurcy and standard deviation tables

# %%
BN1_D = ma.simple_RF(binary_neg1, iter_num = 100)
Teste['bin_neg1_6'] = np.mean(BN1_D[0])
Teste_std['bin_neg1_6'] = np.std(BN1_D[0])
Teste_feat['bin_neg1_6'] = BN1_D[1]

BN1_D = ma.simple_RF(binary_pos1, iter_num = 100)
Teste['bin_pos1_6'] = np.mean(BN1_D[0])
Teste_std['bin_pos1_6'] = np.std(BN1_D[0])
Teste_feat['bin_pos1_6'] = BN1_D[1]

BN1_D = ma.simple_RF(binary_neg2, iter_num = 100)
Teste['bin_neg1_13'] = np.mean(BN1_D[0])
Teste_std['bin_neg1_13'] = np.std(BN1_D[0])
Teste_feat['bin_neg1_13'] = BN1_D[1]

BN1_D = ma.simple_RF(binary_pos2, iter_num = 100)
Teste['bin_pos1_13'] = np.mean(BN1_D[0])
Teste_std['bin_pos1_13'] = np.std(BN1_D[0])
Teste_feat['bin_pos1_13'] = BN1_D[1]

# %%
Teste_H = pd.DataFrame(list(Teste.values()), index = Teste.keys(), columns = ['Accuracy']).T
Teste_std_H = pd.DataFrame(list(Teste_std.values()), index = Teste.keys()).T
Teste_ic = Teste_std_H / (100**0.5)*1.96

# %%
f, ax = plt.subplots(figsize=(20, 9))

plt.bar(height = Teste_H.T['Accuracy'], x = Teste_H.columns, width = 0.5)
ax.errorbar(x = Teste_H.columns, y = Teste_H.T['Accuracy'], yerr = Teste_ic.iloc[0,:], 
            ls = 'none', ecolor = 'black', capsize = 6)
plt.show()

# %%
Teste_H.loc['SD'] = list(Teste_std.values())
Teste_H.T
# Out:
#              Accuracy        SD
# Imp_neg1_6   0.859744  0.077642
# P_neg1_6     0.852564  0.080054
# NP_neg1_6    0.708462  0.095228
# NGP_neg1_6   0.723333  0.101682
# Imp_pos1_6   0.939231  0.059214
# P_pos1_6     0.935128  0.060183
# NP_pos1_6    0.804359  0.101899
# NGP_pos1_6   0.834615  0.086146
# Imp_neg1_13  0.827692  0.092598
# P_neg1_13    0.827949  0.096302
# NP_neg1_13   0.776923  0.093264
# NGP_neg1_13  0.780769  0.087734
# Imp_pos1_13  0.890769  0.084391
# P_pos1_13    0.887949  0.081943
# NP_pos1_13   0.873077  0.079972
# NGP_pos1_13  0.896667  0.076619
# bin_neg1_6   0.932821  0.035303
# bin_pos1_6   0.975897  0.038856
# bin_neg1_13  0.972308  0.036923
# bin_pos1_13  0.972308  0.042394

# %% [markdown]
# #### Applications of different methods

# %%
#Preparations of dicts:
Scores = {}
Scores_std = {}
Imp_feat = {}

# %% [markdown]
# ### Attempt/Method nº1 - Direct
#
# ### Simple application of random forests
#
# Since the dataset is small, the random forest classification is iterated 20 times to make sure more combinations of training and test samples are used. Then, an average of the results are obtained - number of random forests can be decided by iter_num. This is the same for all methods.
#
# To offset the small dataset, 3-fold Cross-Validation is used as an internal validation system evaluating the performance of the model based on its score/accuracy (3-fold since that is maximum number possible since every group of samples only has 3 replicates.
#
# Besides the 3-fold cross-validation score, the order of the average of most important features across the random forests (with each iteration and group in cross-validation having the same weight) is extracted from the forests "built".

# %% [markdown]
# Now to run the random forests on the different datasets (negative and positive of both alignments) both in their "normal" and "binary" matrices form. For the normal or euclidean matrices, only the data concerning the P data processing was used since it was the best performer of all former methods employed.
#
# Application of the function simple_RF from multianalysis.

# %%
N1_D = ma.simple_RF(Euc_P_neg)#(Scores, Cohen's Kappa Score, order of features based on importances, 3-fold cross-validation)
Scores['neg1-6_direct'] = np.mean(N1_D[0])
Scores_std['neg1-6_direct'] = np.std(N1_D[0])
Imp_feat['neg1-6_direct'] = N1_D[1]

# %%
P1_D = ma.simple_RF(Euc_P_pos)
Scores['pos1-6_direct'] = np.mean(P1_D[0])
Scores_std['pos1-6_direct'] = np.std(P1_D[0])
Imp_feat['pos1-6_direct'] = P1_D[1]

# %%
N2_D = ma.simple_RF(Euc_P_neg2)
Scores['neg1-13_direct'] = np.mean(N2_D[0])
Scores_std['neg1-13_direct'] = np.std(N2_D[0])
Imp_feat['neg1-13_direct'] = N2_D[1]

# %%
P2_D = ma.simple_RF(Euc_P_pos2)
Scores['pos1-13_direct'] = np.mean(P2_D[0])
Scores_std['pos1_13_direct'] = np.std(P2_D[0])
Imp_feat['pos1-13_direct'] = P2_D[1]

# %%
BN1_D = ma.simple_RF(binary_neg1)
Scores['neg1-6_bin_direct'] = np.mean(BN1_D[0])
Scores_std['neg1-6_bin_direct'] = np.std(BN1_D[0])
Imp_feat['neg1-6_bin_direct'] = BN1_D[1]

# %%
BP1_D = ma.simple_RF(binary_pos1)
Scores['pos1-6_bin_direct'] = np.mean(BP1_D[0])
Scores_std['pos1-6_bin_direct'] = np.std(BP1_D[0])
Imp_feat['pos1-6_bin_direct'] = BP1_D[1]

# %%
BN2_D = ma.simple_RF(binary_neg2)
Scores['neg1-13_bin_direct'] = np.mean(BN2_D[0])
Scores_std['neg1-13_bin_direct'] = np.std(BN2_D[0])
Imp_feat['neg1-13_bin_direct'] = BN2_D[1]

# %%
BP2_D = ma.simple_RF(binary_pos2)
Scores['pos1-13_bin_direct'] = np.mean(BP2_D[0])
Scores_std['pos1-13_bin_direct'] = np.std(BP2_D[0])
Imp_feat['pos1-13_bin_direct'] = BP2_D[1]

# %% [markdown]
# ### Attempt/Method nº2 - SMOTE
#
# ### Oversampling data with SMOTE before splitting cross-validation groups. Expected better results due to bleed.
#
# All the same specifications as method nº1 but with an oversampling of the data that doubles the amount of samples (from 39 to 78) which means each cross-valdiation group will have 2 replicates for each variety instead of one.
#
# As mentioned in the title, this means there will be a "bleeding" of the data between test and training groups due to the samples in the test group having been originated from the ones in the training group or have been used to originate data in training groups. Therefore, the score of this method should be higher than the other due to an overestimation of how good the model is due to this bleeding.

# %% [markdown]
# SMOTE oversampling is performed in the initial imputated data by the function fast_SMOTE from multianalysis.py.
#
# Therefore we have to run the NGP data processing again for each dataset.

# %%
#Neg1
Imp_S_neg = ma.fast_SMOTE(Imputated_neg)
#Norm_S_neg = sca.Norm_Feat(Imp_S_neg, 554.26202)
#glog_S_neg = sca.glog(Norm_S_neg, 0)
Euc_P_S_neg = sca.ParetoScal(Imp_S_neg)#glog_S_neg)
#Neg2
Imp_S_neg2 = ma.fast_SMOTE(Imputated_neg2)
#Norm_S_neg2 = sca.Norm_Feat(Imp_S_neg2, 554.26202)
#glog_S_neg2 = sca.glog(Norm_S_neg2, 0)
Euc_P_S_neg2 = sca.ParetoScal(Imp_S_neg2)#glog_S_neg2)
#Pos1
Imp_S_pos = ma.fast_SMOTE(Imputated_pos)
#Norm_S_pos = sca.Norm_Feat(Imp_S_pos, 556.2765712820513)
#glog_S_pos = sca.glog(Norm_S_pos, 0)
Euc_P_S_pos = sca.ParetoScal(Imp_S_pos)#glog_S_pos)
#Pos2
Imp_S_pos2 = ma.fast_SMOTE(Imputated_pos2)
#Norm_S_pos2 = sca.Norm_Feat(Imp_S_pos2, 556.2765712820513)
#glog_S_pos2 = sca.glog(Norm_S_pos2, 0)
Euc_P_S_pos2 = sca.ParetoScal(Imp_S_pos2)#glog_S_pos2)
#Binaries
binary_S_neg1 = ma.fast_SMOTE(binary_neg1, binary = True)
binary_S_neg2 = ma.fast_SMOTE(binary_neg2, binary = True)
binary_S_pos1 = ma.fast_SMOTE(binary_pos1, binary = True)
binary_S_pos2 = ma.fast_SMOTE(binary_pos2, binary = True)

# %%
N1_B = ma.simple_RF(Euc_P_S_neg)
Scores['neg1-6_bleed'] = np.mean(N1_B[0])
Scores_std['neg1-6_bleed'] = np.std(N1_B[0])
Imp_feat['neg1-6_bleed'] = N1_B[1]

# %%
P1_B = ma.simple_RF(Euc_P_S_pos)
Scores['pos1-6_bleed'] = np.mean(P1_B[0])
Scores_std['pos1-6_bleed'] = np.std(P1_B[0])
Imp_feat['pos1-6_bleed'] = P1_B[1]

# %%
N2_B = ma.simple_RF(Euc_P_S_neg2)
Scores['neg1-13_bleed'] = np.mean(N2_B[0])
Scores_std['neg1-13_bleed'] = np.std(N2_B[0])
Imp_feat['neg1-13_bleed'] = N2_B[1]

# %%
P2_B = ma.simple_RF(Euc_P_S_pos2)
Scores['pos1-13_bleed'] = np.mean(P2_B[0])
Scores_std['pos1-13_bleed'] = np.std(P2_B[0])
Imp_feat['pos1-13_bleed'] = P2_B[1]

# %%
BN1_B = ma.simple_RF(binary_S_neg1)
Scores['neg1-6_bin_bleed'] = np.mean(BN1_B[0])
Scores_std['neg1-6_bin_bleed'] = np.std(BN1_B[0])
Imp_feat['neg1-6_bin_bleed'] = BN1_B[1]

# %%
BP1_B = ma.simple_RF(binary_S_pos1)
Scores['pos1-6_bin_bleed'] = np.mean(BP1_B[0])
Scores_std['pos1-6_bin_bleed'] = np.std(BP1_B[0])
Imp_feat['pos1-6_bin_bleed'] = BP1_B[1]

# %%
BN2_B = ma.simple_RF(binary_S_neg2)
Scores['neg1-13_bin_bleed'] = np.mean(BN2_B[0])
Scores_std['neg1-13_bin_bleed'] = np.std(BN2_B[0])
Imp_feat['neg1-13_bin_bleed'] = BN2_B[1]

# %%
BP2_B = ma.simple_RF(binary_S_pos2)
Scores['pos1-13_bin_bleed'] = np.mean(BP2_B[0])
Scores_std['pos1-13_bin_bleed'] = np.std(BP2_B[0])
Imp_feat['pos1-13_bin_bleed'] = BP2_B[1]

# %% [markdown]
# ### Attempt/Method nº3 - Afterproc (Euclidean); Aftersplit (Binary)
# Oversampling data with SMOTE after splitting data and after treatment of data (NGP) (binary matrixes don't have any further processing) - Problem: SMOTE after data processing isn't quite the same as in the beginning of the data (vectors between transformed data in different scale than original)
#
# All the same specifications as method nº1.
#
# #### Still possible although probably not very useful, as for now, it won't be implemented in the notebook (method nº4 is the same but completely excised of the notebook.
#
# Application of the function RF_M3 from multianalysis.

# %% [markdown]
# ### Results of the Random Forests surmised in Heatmaps

# %%
Scores_H = pd.DataFrame(list(Scores.values()), index = Scores.keys()).T
Scores_std_H = pd.DataFrame(list(Scores_std.values()), index = Scores_std.keys()).T

#Inserting blank lines in the DataFrame for better presentation and separation
Scores_H = pd.concat([Scores_H.iloc[:,:8], pd.DataFrame(np.empty((1,1))* np.nan, index = ['']).T, Scores_H.iloc[:,8:]], axis = 1)
Scores_std_H = pd.concat([Scores_std_H.iloc[:,:8], pd.DataFrame(np.empty((1,1))* np.nan, index = ['']).T, Scores_std_H.iloc[:,8:]], 
                        axis = 1)

# %%
f, ax = plt.subplots(figsize=(20, 1))
hm = sns.heatmap(Scores_H, annot=True, ax=ax, cmap = sns.cm.rocket_r, yticklabels = ['RF_CV_Scores'])
plt.text(4,-0.2,'Direct', fontsize  = 12, horizontalalignment='center')
plt.text(13,-0.2,'Bleed', fontsize  = 12, horizontalalignment='center')
plt.show()

# %%
f, ax = plt.subplots(figsize=(20, 1))
hm = sns.heatmap(Scores_std_H, annot=True, ax=ax, cmap = sns.cm.rocket_r, yticklabels = ['RF_CV_std'])

# %% [markdown]
# ### Characteristics of the features seen as important in the different alignments, data treatments and modes (negative and positive)
#
# We take the 2% most important features in each case and calculate the average number of samples those features appear (samples_m), the average number of different groups/varieties those features appear in (groups_n) and the ratio between these two measures (ratio_m, has a maximum of 3). We also see how many times the importance of the most importante feature is greater than the average importance of a feature in each case ('magni') as well as the % of the model explained (that use) the 2% of the most important features ('more').
#
# A scatter plot is also built to see the distributions of the number of samples each important feature in each method appears to see their overall distribution.
#
# ### Alignments 1-6 and 1-13

# %%
#Getting the number of samples, groups, ratios for each important feature, magnitude for most important feature and calculating
#% explained by these features (more)
ev = []
magni = []
more = []
for j in Imp_feat:#['neg2-1_direct']:
    if j.startswith('neg1-6'):
        #continue
        Spectra = aligned_all_neg
    elif j.startswith('pos1-6'):
        #continue
        Spectra = aligned_all_pos
    elif j.startswith('neg1-13'):
        #continue
        Spectra = aligned_all_neg2
    elif j.startswith('pos1-13'):
        #continue
        Spectra = aligned_all_pos2
    ratio = []
    nsamples = []
    n_groups = []
    number = round(0.02*len(Spectra))
    magni.append(Imp_feat[j][0][1]/(1/len(Spectra)))
    a = 0
    for i in range(number): 
        a = a + Imp_feat[j][i][1]*100 
        ngroups = {}
        line = Spectra.data.loc[Imp_feat[j][i][2],:].notnull()
        nsamples.append(line.sum())
        for n in range(len(line)):
            if line[n] == True:
                ngroups[Spectra.labels[n]] = 1
        n_groups.append(sum(list((ngroups.values()))))
        ratio.append(nsamples[-1]/n_groups[-1])
    more.append(a)
    df = pd.DataFrame(columns = ['nsamples', 'n_groups', 'ratio'])
    df['nsamples'] = nsamples
    df['n_groups'] = n_groups
    df['ratio']  = ratio
    ev.append(df)
#print(ev[4])

# %%
#Calculating averages of number of samples, groups and ratios and storing information in a DataFrame
ratio_m = []
samples_m = []
groups_m = []
for i in range(len(ev)):
    samples_m.append(np.mean(ev[i].iloc[:,0]))
    groups_m.append(np.mean(ev[i].iloc[:,1]))
    ratio_m.append(np.mean(ev[i].iloc[:,2]))
df = pd.DataFrame(columns = ['samples_m', 'groups_m', 'ratio_m'], index = [i  for i in Imp_feat]) #if '2-1' in i])
df['samples_m'] = samples_m
df['groups_m'] = groups_m
df['ratio_m'] = ratio_m
#print(df)
#Inserting blank lines in the DataFrame for better presentation and separation
line = pd.DataFrame({"samples_m": None, "groups_m": None, 'ratio_m':None}, index=[''])
df = pd.concat([df.iloc[:4], line, df.iloc[4:8], line, df.iloc[8:12], line, df.iloc[12:]])

# %%
f, ax = plt.subplots(figsize=(8, 9))
hm = sns.heatmap(df, annot=True, ax=ax, cmap = sns.cm.rocket_r)
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.text(1.5,-0.5,'Direct Conventional',horizontalalignment='center', verticalalignment='center')
plt.text(1.5,4.5,'Direct Binary',horizontalalignment='center', verticalalignment='center')
plt.text(1.5,9.5,'Bleed Conventional',horizontalalignment='center', verticalalignment='center')
plt.text(1.5,14.5,'Bleed Binary',horizontalalignment='center', verticalalignment='center')
plt.show()

# %%
f, ax = plt.subplots(figsize=(20, 9))
for i in range(len(ev)):
    if '1-6' in list(Imp_feat.keys())[i]:
        plt.scatter([list(Imp_feat.keys())[i][0:12]]*len(ev[i]), ev[i].iloc[:,0])
plt.show()

# %%
f, ax = plt.subplots(figsize=(20, 9))
for i in range(len(ev)):
    if '1-13' in list(Imp_feat.keys())[i]:
        plt.scatter([list(Imp_feat.keys())[i][0:13]]*len(ev[i]), ev[i].iloc[:,0])
plt.show()

# %%
print('Magnitude of most important feature:', magni)
print('% of model explained by the 2% most important features', more)
# Out:
# Magnitude of most important feature: [4.357968869319314, 9.047543672905544, 2.844710076125741, 7.200499779206733, 4.128903274921681, 5.623170240949257, 2.5845060444613606, 4.972413752280584, 6.132610557382235, 11.044657754052597, 2.928150750871508, 7.704362769881505, 5.385662173925179, 7.080305035332722, 3.274978361920941, 5.868969928587518]
# % of model explained by the 2% most important features [6.550963304779683, 9.265997086737604, 5.247632140611136, 9.587297185232377, 5.959196597060879, 8.341551582494269, 5.245912425208485, 6.887338449462224, 7.738145009838088, 10.994372353453086, 5.678797894239863, 10.435146609662079, 8.156739993920572, 10.673262148691435, 6.138785416824777, 8.258924890328702]

# %% [markdown]
# ### See how overfit the random forests built are (only present in this notebook)

# %%
N1_D = ma.overfit_RF(Euc_P_neg)#(Scores, Cohen's Kappa Score, order of features based on importances, 3-fold cross-validation)
Scores['neg1-6_overfit'] = np.mean(N1_D[0])
Scores_std['neg1-6_overfit'] = np.std(N1_D[0])
Imp_feat['neg1-6_overfit'] = N1_D[1]

# %%
P1_D = ma.overfit_RF(Euc_P_pos)
Scores['pos1-6_overfit'] = np.mean(P1_D[0])
Scores_std['pos1-6_overfit'] = np.std(P1_D[0])
Imp_feat['pos1-6_overfit'] = P1_D[1]

# %%
N2_D = ma.overfit_RF(Euc_P_neg2)
Scores['neg1-13_overfit'] = np.mean(N2_D[0])
Scores_std['neg1-13_overfit'] = np.std(N2_D[0])
Imp_feat['neg1-13_overfit'] = N2_D[1]

# %%
P2_D = ma.overfit_RF(Euc_P_pos2)
Scores['pos1-13_overfit'] = np.mean(P2_D[0])
Scores_std['pos1-13_overfit'] = np.std(P2_D[0])
Imp_feat['pos1-13_overfit'] = P2_D[1]

# %%
BN1_D = ma.overfit_RF(binary_neg1)
Scores['neg1-6_bin_overfit'] = np.mean(BN1_D[0])
Scores_std['neg1-6_bin_overfit'] = np.std(BN1_D[0])
Imp_feat['neg1-6_bin_overfit'] = BN1_D[1]

# %%
BP1_D = ma.overfit_RF(binary_pos1)
Scores['pos1-6_bin_overfit'] = np.mean(BP1_D[0])
Scores_std['pos1-6_bin_overfit'] = np.std(BP1_D[0])
Imp_feat['pos1-6_bin_overfit'] = BP1_D[1]

# %%
BN2_D = ma.overfit_RF(binary_neg2)
Scores['neg1-13_bin_overfit'] = np.mean(BN2_D[0])
Scores_std['neg1-13_bin_overfit'] = np.std(BN2_D[0])
Imp_feat['neg1-13_bin_overfit'] = BN2_D[1]

# %%
BP2_D = ma.overfit_RF(binary_pos2)
Scores['pos1-13_bin_overfit'] = np.mean(BP2_D[0])
Scores_std['pos1-13_bin_overfit'] = np.std(BP2_D[0])
Imp_feat['pos1-13_bin_overfit'] = BP2_D[1]

# %%
Scores_H = pd.DataFrame(list(Scores.values()), index = Scores.keys()).T
Scores_std_H = pd.DataFrame(list(Scores_std.values()), index = Scores_std.keys()).T

# %%
f, ax = plt.subplots(figsize=(20, 1))
hm = sns.heatmap(Scores_H[['neg1-6_overfit','neg1-13_overfit','pos1-6_overfit','pos1-13_overfit',
                          'neg1-6_bin_overfit','neg1-13_bin_overfit','pos1-6_bin_overfit','pos1-13_bin_overfit',
                          'neg1-6_direct','neg1-13_direct','pos1-6_direct','pos1-13_direct',
                          'neg1-6_bin_direct','neg1-13_bin_direct','pos1-6_bin_direct','pos1-13_bin_direct']], annot=True, 
                 ax=ax, cmap = sns.cm.rocket_r, yticklabels = ['RF_Scores'])

# %% [markdown]
# ### PLS-DA - Classification based on Partial Least Squares - Discriminant Analysis
#
# Creating the target vectors matrix where each different group is made into a column and 1 represents the sample belongs to that group (0 means it doesn't belong).

# %%
matrix = pd.get_dummies(aligned_all_neg.labels)
matrix = matrix[['CAN','CS','LAB','PN','REG','RIP','RL','ROT','RU','TRI','CFN','CHT','SB']]

# %% [markdown]
# ## Alignment 1-6
#
# ### Search for the best number of components to use
#
# Strategy: Perform PLS-DA with different number of components and observe the score (both given directly by the method and the r2 score) and the mean-squared error (MSE) of the models built with 3-fold cross-validation (3 was chosen since it is the max for our dataset - 3 replicates in each group, having an added bonus of still maintaining a balanced dataset). Then plot the different results obtained and see at which point (number of components) the score and the MSE stops start approaching a "stable value".
#
# The maximum number of components tested was 50 (which was enough for the objective established above).
#
# Warnings are due to the type of scoring that will be changed in the next version of scikit learn.
#
# Function optim_PLS in multianalysis.py - performs PLS analysis and obtains the results stated above with number of components defined from 1 to max_comp.

# %%
# %%capture
#PLS applied in the negative dataset.
P_neg_PLS = ma.optim_PLS(Euc_P_neg, matrix, max_comp = 50)
NP_neg_PLS = ma.optim_PLS(Euc_NP_neg, matrix, max_comp = 50)
NGP_neg_PLS = ma.optim_PLS(Euc_NGP_neg, matrix, max_comp = 50)
bin_neg_PLS = ma.optim_PLS(binary_neg1, matrix, max_comp = 50)

#PLS applied in the positive dataset.
P_pos_PLS = ma.optim_PLS(Euc_P_pos, matrix, max_comp = 50)
NP_pos_PLS = ma.optim_PLS(Euc_NP_pos, matrix, max_comp = 50)
NGP_pos_PLS = ma.optim_PLS(Euc_NGP_pos, matrix, max_comp = 50)
bin_pos_PLS = ma.optim_PLS(binary_pos1, matrix, max_comp = 50)

# %%
f, ax = plt.subplots(figsize=(8,6))
plt.plot(range(1,51),P_neg_PLS[0])
plt.plot(range(1,51),NP_neg_PLS[0])
plt.plot(range(1,51),NGP_neg_PLS[0])
plt.plot(range(1,51),bin_neg_PLS[0])
plt.ylabel('PLS-DA Score')
plt.xlabel('Number of Components')
ax.legend(('P', 'NP', 'NGP', 'Binary'))
print('Performance based on number of components - Alignment: 1-6, Negative Mode')
# Out:
# Performance based on number of components - Alignment: 1-6, Negative Mode

# %%
f, ax = plt.subplots(figsize=(8,6))
plt.plot(range(1,51),P_neg_PLS[2])
plt.plot(range(1,51),NP_neg_PLS[2])
plt.plot(range(1,51),NGP_neg_PLS[2])
plt.plot(range(1,51),bin_neg_PLS[2])
plt.ylabel('Mean Squared Error of Predictions')
plt.xlabel('Number of Components')
ax.legend(('P', 'NP', 'NGP', 'Binary'))
print('Performance based on number of components - Alignment: 1-6, Negative Mode')
# Out:
# Performance based on number of components - Alignment: 1-6, Negative Mode

# %%
f, ax = plt.subplots(figsize=(8,6))
plt.plot(range(1,51),P_pos_PLS[0])
plt.plot(range(1,51),NP_pos_PLS[0])
plt.plot(range(1,51),NGP_pos_PLS[0])
plt.plot(range(1,51),bin_pos_PLS[0])
plt.ylabel('PLS-DA Score')
plt.xlabel('Number of Components')
ax.legend(('P', 'NP', 'NGP', 'Binary'))
print('Performance based on number of components - Alignment: 1-6, Negative Mode')
# Out:
# Performance based on number of components - Alignment: 1-6, Negative Mode

# %%
f, ax = plt.subplots(figsize=(8,6))
plt.plot(range(1,51),P_pos_PLS[2])
plt.plot(range(1,51),NP_pos_PLS[2])
plt.plot(range(1,51),NGP_pos_PLS[2])
plt.plot(range(1,51),bin_pos_PLS[2])
plt.ylabel('Mean Squared Error of Predictions')
plt.xlabel('Number of Components')
ax.legend(('P', 'NP', 'NGP', 'Binary'))
print('Performance based on number of components - Alignment: 1-6, Negative Mode')
# Out:
# Performance based on number of components - Alignment: 1-6, Negative Mode

# %% [markdown]
# ### Application of PLS-DA
#
# The number of components where the evaluating metrics stopped getting considerably better when it reached around 15.
#
# We can now transform the PLS algorithm (PLS2 algorithm used) to give classification of samples instead of regression using a decision rule to interpret the y_pred result given for each test sample and decide what group it belongs to. In this case a simple rule of the group with the highest number (closer to 1) is decided to be the group to which said sample belongs to - naive MAX rule.
#
# Two metrics to evaluate the results were evaluated. First the score of the model as seen before but more importantly the second one is the accuracy of the model based on the decision rule stated above. All samples are tested once in 3 different groups as 3-fold cross-validation.

# %%
PLS_accu = {}
PLS_score = {}
PLS_weights = {}
PLS_RegCoef = {}

# %%
# %%capture
P_neg_PLS = ma.model_PLSDA(Euc_P_neg, matrix, n_comp = 15, iter_num = 25)
PLS_accu['P_neg'] = P_neg_PLS[0]
PLS_score['P_neg'] = P_neg_PLS[1]
PLS_weights['P_neg'] = P_neg_PLS[3]
PLS_RegCoef['P_neg'] = P_neg_PLS[4]

NP_neg_PLS = ma.model_PLSDA(Euc_NP_neg, matrix, n_comp = 15, iter_num = 25)
PLS_accu['NP_neg'] = NP_neg_PLS[0]
PLS_score['NP_neg'] = NP_neg_PLS[1]
PLS_weights['NP_neg'] = NP_neg_PLS[3]
PLS_RegCoef['NP_neg'] = NP_neg_PLS[4]

NGP_neg_PLS = ma.model_PLSDA(Euc_NGP_neg, matrix, n_comp = 15, iter_num = 25)
PLS_accu['NGP_neg'] = NGP_neg_PLS[0]
PLS_score['NGP_neg'] = NGP_neg_PLS[1]
PLS_weights['NGP_neg'] = NGP_neg_PLS[3]
PLS_RegCoef['NGP_neg'] = NGP_neg_PLS[4]

bin_neg_PLS = ma.model_PLSDA(binary_neg1, matrix, n_comp = 15, iter_num = 25)
PLS_accu['bin_neg'] = bin_neg_PLS[0]
PLS_score['bin_neg'] = bin_neg_PLS[1]
PLS_weights['bin_neg'] = bin_neg_PLS[3]
PLS_RegCoef['bin_neg'] = bin_neg_PLS[4]

# %%
# %%capture
P_pos_PLS = ma.model_PLSDA(Euc_P_pos, matrix, n_comp = 15, iter_num = 25)
PLS_accu['P_pos'] = P_pos_PLS[0]
PLS_score['P_pos'] = P_pos_PLS[1]
PLS_weights['P_pos'] = P_pos_PLS[3]
PLS_RegCoef['P_pos'] = P_pos_PLS[4]

NP_pos_PLS = ma.model_PLSDA(Euc_NP_pos, matrix, n_comp = 15, iter_num = 25)
PLS_accu['NP_pos'] = NP_pos_PLS[0]
PLS_score['NP_pos'] = NP_pos_PLS[1]
PLS_weights['NP_pos'] = NP_pos_PLS[3]
PLS_RegCoef['NP_pos'] = NP_pos_PLS[4]

NGP_pos_PLS = ma.model_PLSDA(Euc_NGP_pos, matrix, n_comp = 15, iter_num = 25)
PLS_accu['NGP_pos'] = NGP_pos_PLS[0]
PLS_score['NGP_pos'] = NGP_pos_PLS[1]
PLS_weights['NGP_pos'] = NGP_pos_PLS[3]
PLS_RegCoef['NGP_pos'] = NGP_pos_PLS[4]

bin_pos_PLS = ma.model_PLSDA(binary_pos1, matrix, n_comp = 15, iter_num = 25)
PLS_accu['bin_pos'] = bin_pos_PLS[0]
PLS_score['bin_pos'] = bin_pos_PLS[1]
PLS_weights['bin_pos'] = bin_pos_PLS[3]
PLS_RegCoef['bin_pos'] = bin_pos_PLS[4]

# %%
f, ax = plt.subplots(figsize=(12,6))
plt.scatter(['P_neg_1_6']*len(PLS_accu['P_neg']), PLS_accu['P_neg'])
plt.scatter(['NP_neg_1_6']*len(PLS_accu['NP_neg']), PLS_accu['NP_neg'])
plt.scatter(['NGP_neg_1_6']*len(PLS_accu['NGP_neg']), PLS_accu['NGP_neg'])
plt.scatter(['bin_neg_1_6']*len(PLS_accu['bin_neg']), PLS_accu['bin_neg'])
plt.scatter(['P_pos_1_6']*len(PLS_accu['P_pos']), PLS_accu['P_pos'])
plt.scatter(['NP_pos_1_6']*len(PLS_accu['NP_pos']), PLS_accu['NP_pos'])
plt.scatter(['NGP_pos_1_6']*len(PLS_accu['NGP_pos']), PLS_accu['NGP_pos'])
plt.scatter(['bin_pos_1_6']*len(PLS_accu['bin_pos']), PLS_accu['bin_pos'])
plt.ylabel('PLS-DA Model Accuracy')
print('Accuracy based on the dataset - Alignment: 1-6, Negative and Positive Mode')
# Out:
# Accuracy based on the dataset - Alignment: 1-6, Negative and Positive Mode

# %%
df = pd.DataFrame.from_dict(PLS_accu)
f, ax = plt.subplots(figsize=(20, 9))
df.boxplot()
plt.scatter(['P_neg2']*len(PLS_accu['P_neg']), [1]*len(PLS_accu['P_neg']))
plt.scatter(['P_neg']*len(PLS_accu['P_neg']), PLS_accu['P_neg'])
plt.scatter(['NP_neg']*len(PLS_accu['NP_neg']), PLS_accu['NP_neg'])
plt.scatter(['NGP_neg']*len(PLS_accu['NGP_neg']), PLS_accu['NGP_neg'])
plt.scatter(['bin_neg']*len(PLS_accu['bin_neg']), PLS_accu['bin_neg'])
plt.scatter(['P_pos']*len(PLS_accu['P_pos']), PLS_accu['P_pos'])
plt.scatter(['NP_pos']*len(PLS_accu['NP_pos']), PLS_accu['NP_pos'])
plt.scatter(['NGP_pos']*len(PLS_accu['NGP_pos']), PLS_accu['NGP_pos'])
plt.scatter(['bin_pos']*len(PLS_accu['bin_pos']), PLS_accu['bin_pos'])
plt.show()

# %%
f, ax = plt.subplots(figsize=(12,6))
plt.scatter(['P_neg_1_6']*len(PLS_score['P_neg']), PLS_score['P_neg'])
plt.scatter(['NP_neg_1_6']*len(PLS_score['NP_neg']), PLS_score['NP_neg'])
plt.scatter(['NGP_neg_1_6']*len(PLS_score['NGP_neg']), PLS_score['NGP_neg'])
plt.scatter(['bin_neg_1_6']*len(PLS_score['bin_neg']), PLS_score['bin_neg'])
plt.scatter(['P_pos_1_6']*len(PLS_score['P_pos']), PLS_score['P_pos'])
plt.scatter(['NP_pos_1_6']*len(PLS_score['NP_pos']), PLS_score['NP_pos'])
plt.scatter(['NGP_pos_1_6']*len(PLS_score['NGP_pos']), PLS_score['NGP_pos'])
plt.scatter(['bin_pos_1_6']*len(PLS_score['bin_pos']), PLS_score['bin_pos'])
plt.ylabel('PLS-DA Model Score')
print('Performance score based on the dataset - Alignment: 1-6, Negative and Positive Mode')
# Out:
# Performance score based on the dataset - Alignment: 1-6, Negative and Positive Mode

# %%
Accuracy = {}
Accuracy['P_neg_1_6'] = np.mean(PLS_accu['P_neg'])
Accuracy['NP_neg_1_6'] = np.mean(PLS_accu['NP_neg'])
Accuracy['NGP_neg_1_6'] = np.mean(PLS_accu['NGP_neg'])
Accuracy['bin_neg_1_6'] = np.mean(PLS_accu['bin_neg'])
Accuracy['P_pos_1_6'] = np.mean(PLS_accu['P_pos'])
Accuracy['NP_pos_1_6'] = np.mean(PLS_accu['NP_pos'])
Accuracy['NGP_pos_1_6'] = np.mean(PLS_accu['NGP_pos'])
Accuracy['bin_pos_1_6'] = np.mean(PLS_accu['bin_pos'])

# %%
Accuracy_H = pd.DataFrame(list(Accuracy.values()), index = Accuracy.keys()).T
f, ax = plt.subplots(figsize=(10, 1))
hm = sns.heatmap(Accuracy_H, annot=True, ax=ax, cmap = sns.cm.rocket_r, yticklabels = ['PLSDA_Accuracy'])

# %%
Score = {}
Score['P_neg_1_6'] = np.mean(PLS_score['P_neg'])
Score['NP_neg_1_6'] = np.mean(PLS_score['NP_neg'])
Score['NGP_neg_1_6'] = np.mean(PLS_score['NGP_neg'])
Score['bin_neg_1_6'] = np.mean(PLS_score['bin_neg'])
Score['P_pos_1_6'] = np.mean(PLS_score['P_pos'])
Score['NP_pos_1_6'] = np.mean(PLS_score['NP_pos'])
Score['NGP_pos_1_6'] = np.mean(PLS_score['NGP_pos'])
Score['bin_pos_1_6'] = np.mean(PLS_score['bin_pos'])

# %%
Score_H = pd.DataFrame(list(Score.values()), index = Score.keys()).T
f, ax = plt.subplots(figsize=(10, 1))
hm = sns.heatmap(Score_H, annot=True, ax=ax, cmap = sns.cm.rocket_r, yticklabels = ['PLSDA_Score'])

# %%
Accuracy_std = {}
Accuracy_std['P_neg_1_6'] = np.std(PLS_accu['P_neg'])
Accuracy_std['NP_neg_1_6'] = np.std(PLS_accu['NP_neg'])
Accuracy_std['NGP_neg_1_6'] = np.std(PLS_accu['NGP_neg'])
Accuracy_std['bin_neg_1_6'] = np.std(PLS_accu['bin_neg'])
Accuracy_std['P_pos_1_6'] = np.std(PLS_accu['P_pos'])
Accuracy_std['NP_pos_1_6'] = np.std(PLS_accu['NP_pos'])
Accuracy_std['NGP_pos_1_6'] = np.std(PLS_accu['NGP_pos'])
Accuracy_std['bin_pos_1_6'] = np.std(PLS_accu['bin_pos'])

# %%
Score_std = {}
Score_std['P_neg_1_6'] = np.std(PLS_score['P_neg'])
Score_std['NP_neg_1_6'] = np.std(PLS_score['NP_neg'])
Score_std['NGP_neg_1_6'] = np.std(PLS_score['NGP_neg'])
Score_std['bin_neg_1_6'] = np.std(PLS_score['bin_neg'])
Score_std['P_pos_1_6'] = np.std(PLS_score['P_pos'])
Score_std['NP_pos_1_6'] = np.std(PLS_score['NP_pos'])
Score_std['NGP_pos_1_6'] = np.std(PLS_score['NGP_pos'])
Score_std['bin_pos_1_6'] = np.std(PLS_score['bin_pos'])

# %%
Accuracy_H = pd.DataFrame(list(Accuracy.values()), index = Accuracy.keys(), columns  = ['Accuracy']).T
Accuracy_H.loc['SD'] = list(Accuracy_std.values())
Accuracy_H.T
# Out:
#              Accuracy        SD
# P_neg_1_6    0.898462  0.021119
# NP_neg_1_6   0.962051  0.014721
# NGP_neg_1_6  0.938462  0.021757
# bin_neg_1_6  0.963077  0.012728
# P_pos_1_6    0.915897  0.019888
# NP_pos_1_6   0.993846  0.010951
# NGP_pos_1_6  1.000000  0.000000
# bin_pos_1_6  0.986667  0.012810

# %%
Score_H = pd.DataFrame(list(Score.values()), index = Score.keys(), columns  = ['Score']).T
Score_H.loc['SD'] = list(Score_std.values())
Score_H.T
# Out:
#                 Score        SD
# P_neg_1_6    0.591808  0.084574
# NP_neg_1_6   0.747950  0.014805
# NGP_neg_1_6  0.699163  0.030249
# bin_neg_1_6  0.786391  0.004976
# P_pos_1_6    0.683456  0.035452
# NP_pos_1_6   0.692059  0.012547
# NGP_pos_1_6  0.771074  0.005364
# bin_pos_1_6  0.741583  0.003428

# %% [markdown]
# ### Characteristics of the most important features

# %% [markdown]
# The characteristics of the most important features for each of the methods is done by the same process as applied in the random forests section of the notebook.

# %%
#Getting the number of samples, groups, ratios for each important feature, magnitude for most important feature 
Imp_feat = (PLS_weights, PLS_RegCoef)
ev = []
magni = []
index = []
for m in Imp_feat:
    for j in m:
        if j.endswith('neg'):
            Spectra = aligned_all_neg
        elif j.endswith('pos'):
            Spectra = aligned_all_pos
        index.append(j)
        ratio = []
        nsamples = []
        n_groups = []
        number = round(0.02*len(Spectra))
        total_m = 0
        for i in range(len(m[j])):
            total_m = total_m + m[j][i][1]
        magni.append(m[j][0][1]/(total_m/len(Spectra)))
        for i in range(number): 
            ngroups = {}
            line = Spectra.data.loc[m[j][i][2],:].notnull()
            nsamples.append(line.sum())
            for n in range(len(line)):
                if line[n] == True:
                    ngroups[Spectra.labels[n]] = 1
            n_groups.append(sum(list((ngroups.values()))))
            ratio.append(nsamples[-1]/n_groups[-1])
        df = pd.DataFrame(columns = ['nsamples', 'n_groups', 'ratio'])
        df['nsamples'] = nsamples
        df['n_groups'] = n_groups
        df['ratio']  = ratio
        ev.append(df)

# %%
#Calculating averages of number of samples, groups and ratios and storing information in a DataFrame
ratio_m = []
samples_m = []
groups_m = []
for i in range(len(ev)):
    samples_m.append(np.mean(ev[i].iloc[:,0]))
    groups_m.append(np.mean(ev[i].iloc[:,1]))
    ratio_m.append(np.mean(ev[i].iloc[:,2]))
df = pd.DataFrame(columns = ['samples_m', 'groups_m', 'ratio_m'], index = index)
df['samples_m'] = samples_m
df['groups_m'] = groups_m
df['ratio_m'] = ratio_m
#print(df)
#Inserting blank lines in the DataFrame for better presentation and separation
line = pd.DataFrame({"samples_m": None, "groups_m": None, 'ratio_m':None}, index=[''])
df = pd.concat([df.iloc[:8], line, df.iloc[8:]])

# %%
f, ax = plt.subplots(figsize=(12, 9))
hm = sns.heatmap(df, annot=True, ax=ax, cmap = sns.cm.rocket_r)
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.text(1.5,-0.5,'PLS_Weights',horizontalalignment='center', verticalalignment='center')
plt.text(1.5,8.5,'PLS_RegCoef',horizontalalignment='center', verticalalignment='center')
plt.show()

# %%
print('Magnitude of most important features for each case:')
print(magni)
# Out:
# Magnitude of most important features for each case:
# [2.1969107690607994, 2.680811153689479, 2.2218844323688582, 1.7483158455336898, 2.877720785681104, 2.4569212842658907, 2.560782102159914, 2.0186347643834384, 6.049851458690477, 4.601871506135902, 5.169294740551401, 2.9406668571666756, 7.119842033952855, 4.969930715997493, 5.997035837222541, 4.310232044803848]

# %% [markdown]
# ### Model with the full dataset and sample representation on the two most important Components/Latent Variables
#
# NGP data treatment for the negative mode

# %%
from sklearn.cross_decomposition import PLSRegression

# %%
plsda = PLSRegression(n_components = 15)
#Fitting the model and getting the X_scores
plsda.fit(X=Euc_NGP_neg.data.T,Y=matrix)
LV_score = pd.DataFrame(plsda.x_scores_)

#Preparing colours to separate different groups
colours = cm.get_cmap('nipy_spectral', 13)
col_lbl = colours(range(13))
col_lbl = list(col_lbl)
for i in range(len(col_lbl)):
    a = 3*i
    col_lbl.insert(a+1,col_lbl[a])
    col_lbl.insert(a+2,col_lbl[a])

    #Scatter plot
ax = LV_score.iloc[:,0:2].plot(x=0, y=1, kind='scatter', s=50, alpha=0.7, c = col_lbl, figsize=(9,9))
#Labeling each point
i = -1
for n, x in enumerate(LV_score.values): 
    if n%3 == 0:
        i = i + 1
        label = Spectra.unique_labels()[i]
                #label = LV_score.index.values[n]
    ax.text(x[0],x[1],label, fontsize = 8)

# %% [markdown]
# Binary processed data for the negative mode

# %%
plsda = PLSRegression(n_components = 15)
#Fitting the model and getting the X_scores
plsda.fit(X=binary_neg1.data.T,Y=matrix)
LV_score = pd.DataFrame(plsda.x_scores_)

#Preparing colours to separate different groups
colours = cm.get_cmap('nipy_spectral', 13)
col_lbl = colours(range(13))
col_lbl = list(col_lbl)
for i in range(len(col_lbl)):
    a = 3*i
    col_lbl.insert(a+1,col_lbl[a])
    col_lbl.insert(a+2,col_lbl[a])

#Scatter plot
ax = LV_score.iloc[:,0:2].plot(x=0, y=1, kind='scatter', s=50, alpha=0.7, c = col_lbl, figsize=(9,9))
#Labeling each point
i = -1
for n, x in enumerate(LV_score.values): 
    if n%3 == 0:
        i = i + 1
        label = Spectra.unique_labels()[i]
                #label = LV_score.index.values[n]
    ax.text(x[0],x[1],label, fontsize = 8)

# %% [markdown]
# ## Alignment 1-13
#
# ### Search for the best number of components to use
#
# Strategy: Perform PLS-DA with different number of components and observe the score (both given directly by the method and the r2 score) and the mean-squared error (MSE) of the models built with 3-fold cross-validation (3 was chosen since it is the max for our dataset - 3 replicates in each group, having an added bonus of still maintaining a balanced dataset). Then plot the different results obtained and see at which point (number of components) the score and the MSE stops start approaching a "stable value".
#
# The maximum number of components tested was 50 (which was enough for the objective established above).
#
# Warnings are due to the type of scoring that will be changed in the next version of scikit learn.
#
# Function optim_PLS in multianalysis.py - performs PLS analysis and obtains the results stated above with number of components defined from 1 to max_comp.

# %%
# %%capture
#PLS applied in the negative dataset.
P_neg_PLS = ma.optim_PLS(Euc_P_neg2, matrix, max_comp = 50)
NP_neg_PLS = ma.optim_PLS(Euc_NP_neg2, matrix, max_comp = 50)
NGP_neg_PLS = ma.optim_PLS(Euc_NGP_neg2, matrix, max_comp = 50)
bin_neg_PLS = ma.optim_PLS(binary_neg2, matrix, max_comp = 50)

#PLS applied in the positive dataset.
P_pos_PLS = ma.optim_PLS(Euc_P_pos2, matrix, max_comp = 50)
NP_pos_PLS = ma.optim_PLS(Euc_NP_pos2, matrix, max_comp = 50)
NGP_pos_PLS = ma.optim_PLS(Euc_NGP_pos2, matrix, max_comp = 50)
bin_pos_PLS = ma.optim_PLS(binary_pos2, matrix, max_comp = 50)

# %%
f, ax = plt.subplots(figsize=(8,6))
plt.plot(range(1,51),P_neg_PLS[0])
plt.plot(range(1,51),NP_neg_PLS[0])
plt.plot(range(1,51),NGP_neg_PLS[0])
plt.plot(range(1,51),bin_neg_PLS[0])
plt.ylabel('PLS-DA Score')
plt.xlabel('Number of Components')
ax.legend(('P', 'NP', 'NGP', 'Binary'))
print('Performance based on number of components - Alignment: 1-13, Negative Mode')
# Out:
# Performance based on number of components - Alignment: 1-13, Negative Mode

# %%
f, ax = plt.subplots(figsize=(8,6))
plt.plot(range(1,51),P_pos_PLS[0])
plt.plot(range(1,51),NP_pos_PLS[0])
plt.plot(range(1,51),NGP_pos_PLS[0])
plt.plot(range(1,51),bin_pos_PLS[0])
plt.ylabel('PLS-DA Score')
plt.xlabel('Number of Components')
ax.legend(('P', 'NP', 'NGP', 'Binary'))
print('Performance based on number of components - Alignment: 1-13, Positive Mode')
# Out:
# Performance based on number of components - Alignment: 1-13, Positive Mode

# %% [markdown]
# ### Application of PLS-DA
#
# The number of components where the evaluating metrics stopped getting considerably better when it reached around 15.
#
# We can now transform the PLS algorithm (PLS2 algorithm used) to give classification of samples instead of regression using a decision rule to interpret the y_pred result given for each test sample and decide what group it belongs to. In this case a simple rule of the group with the highest number (closer to 1) is decided to be the group to which said sample belongs to - naive MAX rule.
#
# Two metrics to evaluate the results were evaluated. First the score of the model as seen before but more importantly the second one is the accuracy of the model based on the decision rule stated above. All samples are tested once in 3 different groups as 3-fold cross-validation.

# %%
PLS_accu = {}
PLS_score = {}
PLS_weights = {}
PLS_RegCoef = {}

# %%
# %%capture
P_neg_PLS = ma.model_PLSDA(Euc_P_neg2, matrix, n_comp = 15, iter_num = 25)
PLS_accu['P_neg'] = P_neg_PLS[0]
PLS_score['P_neg'] = P_neg_PLS[1]
PLS_weights['P_neg'] = P_neg_PLS[3]
PLS_RegCoef['P_neg'] = P_neg_PLS[4]

NP_neg_PLS = ma.model_PLSDA(Euc_NP_neg2, matrix, n_comp = 15, iter_num = 25)
PLS_accu['NP_neg'] = NP_neg_PLS[0]
PLS_score['NP_neg'] = NP_neg_PLS[1]
PLS_weights['NP_neg'] = NP_neg_PLS[3]
PLS_RegCoef['NP_neg'] = NP_neg_PLS[4]

NGP_neg_PLS = ma.model_PLSDA(Euc_NGP_neg2, matrix, n_comp = 15, iter_num = 25)
PLS_accu['NGP_neg'] = NGP_neg_PLS[0]
PLS_score['NGP_neg'] = NGP_neg_PLS[1]
PLS_weights['NGP_neg'] = NGP_neg_PLS[3]
PLS_RegCoef['NGP_neg'] = NGP_neg_PLS[4]

bin_neg_PLS = ma.model_PLSDA(binary_neg2, matrix, n_comp = 15, iter_num = 25)
PLS_accu['bin_neg'] = bin_neg_PLS[0]
PLS_score['bin_neg'] = bin_neg_PLS[1]
PLS_weights['bin_neg'] = bin_neg_PLS[3]
PLS_RegCoef['bin_neg'] = bin_neg_PLS[4]

# %%
# %%capture
P_pos_PLS = ma.model_PLSDA(Euc_P_pos2, matrix, n_comp = 15, iter_num = 25)
PLS_accu['P_pos'] = P_pos_PLS[0]
PLS_score['P_pos'] = P_pos_PLS[1]
PLS_weights['P_pos'] = P_pos_PLS[3]
PLS_RegCoef['P_pos'] = P_pos_PLS[4]

NP_pos_PLS = ma.model_PLSDA(Euc_NP_pos2, matrix, n_comp = 15, iter_num = 25)
PLS_accu['NP_pos'] = NP_pos_PLS[0]
PLS_score['NP_pos'] = NP_pos_PLS[1]
PLS_weights['NP_pos'] = NP_pos_PLS[3]
PLS_RegCoef['NP_pos'] = NP_pos_PLS[4]

NGP_pos_PLS = ma.model_PLSDA(Euc_NGP_pos2, matrix, n_comp = 15, iter_num = 25)
PLS_accu['NGP_pos'] = NGP_pos_PLS[0]
PLS_score['NGP_pos'] = NGP_pos_PLS[1]
PLS_weights['NGP_pos'] = NGP_pos_PLS[3]
PLS_RegCoef['NGP_pos'] = NGP_pos_PLS[4]

bin_pos_PLS = ma.model_PLSDA(binary_pos2, matrix, n_comp = 15, iter_num = 25)
PLS_accu['bin_pos'] = bin_pos_PLS[0]
PLS_score['bin_pos'] = bin_pos_PLS[1]
PLS_weights['bin_pos'] = bin_pos_PLS[3]
PLS_RegCoef['bin_pos'] = bin_pos_PLS[4]

# %%
f, ax = plt.subplots(figsize=(12,6))
plt.scatter(['P_neg_1_13']*len(PLS_accu['P_neg']), PLS_accu['P_neg'])
plt.scatter(['NP_neg_1_13']*len(PLS_accu['NP_neg']), PLS_accu['NP_neg'])
plt.scatter(['NGP_neg_1_13']*len(PLS_accu['NGP_neg']), PLS_accu['NGP_neg'])
plt.scatter(['bin_neg_1_13']*len(PLS_accu['bin_neg']), PLS_accu['bin_neg'])
plt.scatter(['P_pos_1_13']*len(PLS_accu['P_pos']), PLS_accu['P_pos'])
plt.scatter(['NP_pos_1_13']*len(PLS_accu['NP_pos']), PLS_accu['NP_pos'])
plt.scatter(['NGP_pos_1_13']*len(PLS_accu['NGP_pos']), PLS_accu['NGP_pos'])
plt.scatter(['bin_pos_1_13']*len(PLS_accu['bin_pos']), PLS_accu['bin_pos'])
plt.ylabel('PLS-DA Model Accuracy')
print('Accuracy based on the dataset - Alignment: 1-13, Negative and Positive Mode')
# Out:
# Accuracy based on the dataset - Alignment: 1-13, Negative and Positive Mode

# %%
f, ax = plt.subplots(figsize=(12,6))
plt.scatter(['P_neg_1_13']*len(PLS_score['P_neg']), PLS_score['P_neg'])
plt.scatter(['NP_neg_1_13']*len(PLS_score['NP_neg']), PLS_score['NP_neg'])
plt.scatter(['NGP_neg_1_13']*len(PLS_score['NGP_neg']), PLS_score['NGP_neg'])
plt.scatter(['bin_neg_1_13']*len(PLS_score['bin_neg']), PLS_score['bin_neg'])
plt.scatter(['P_pos_1_13']*len(PLS_score['P_pos']), PLS_score['P_pos'])
plt.scatter(['NP_pos_1_13']*len(PLS_score['NP_pos']), PLS_score['NP_pos'])
plt.scatter(['NGP_pos_1_13']*len(PLS_score['NGP_pos']), PLS_score['NGP_pos'])
plt.scatter(['bin_pos_1_13']*len(PLS_score['bin_pos']), PLS_score['bin_pos'])
plt.ylabel('PLS-DA Model Score')
print('Performance score based on the dataset - Alignment: 1-13, Negative and Positive Mode')
# Out:
# Performance score based on the dataset - Alignment: 1-13, Negative and Positive Mode

# %%
Accuracy = {}
Accuracy['P_neg_1_13'] = np.mean(PLS_accu['P_neg'])
Accuracy['NP_neg_1_13'] = np.mean(PLS_accu['NP_neg'])
Accuracy['NGP_neg_1_13'] = np.mean(PLS_accu['NGP_neg'])
Accuracy['bin_neg_1_13'] = np.mean(PLS_accu['bin_neg'])
Accuracy['P_pos_1_13'] = np.mean(PLS_accu['P_pos'])
Accuracy['NP_pos_1_13'] = np.mean(PLS_accu['NP_pos'])
Accuracy['NGP_pos_1_13'] = np.mean(PLS_accu['NGP_pos'])
Accuracy['bin_pos_1_13'] = np.mean(PLS_accu['bin_pos'])

# %%
Accuracy_H = pd.DataFrame(list(Accuracy.values()), index = Accuracy.keys()).T
f, ax = plt.subplots(figsize=(10, 1))
hm = sns.heatmap(Accuracy_H, annot=True, ax=ax, cmap = sns.cm.rocket_r, yticklabels = ['PLSDA_Accuracy'])

# %%
Score = {}
Score['P_neg_1_13'] = np.mean(PLS_score['P_neg'])
Score['NP_neg_1_13'] = np.mean(PLS_score['NP_neg'])
Score['NGP_neg_1_13'] = np.mean(PLS_score['NGP_neg'])
Score['bin_neg_1_13'] = np.mean(PLS_score['bin_neg'])
Score['P_pos_1_13'] = np.mean(PLS_score['P_pos'])
Score['NP_pos_1_13'] = np.mean(PLS_score['NP_pos'])
Score['NGP_pos_1_13'] = np.mean(PLS_score['NGP_pos'])
Score['bin_pos_1_13'] = np.mean(PLS_score['bin_pos'])

# %%
Score_H = pd.DataFrame(list(Score.values()), index = Score.keys()).T
f, ax = plt.subplots(figsize=(10, 1))
hm = sns.heatmap(Score_H, annot=True, ax=ax, cmap = sns.cm.rocket_r, yticklabels = ['PLSDA_Score'])

# %%
Accuracy_std = {}
Accuracy_std['P_neg_1_13'] = np.std(PLS_accu['P_neg'])
Accuracy_std['NP_neg_1_13'] = np.std(PLS_accu['NP_neg'])
Accuracy_std['NGP_neg_1_13'] = np.std(PLS_accu['NGP_neg'])
Accuracy_std['bin_neg_1_13'] = np.std(PLS_accu['bin_neg'])
Accuracy_std['P_pos_1_13'] = np.std(PLS_accu['P_pos'])
Accuracy_std['NP_pos_1_13'] = np.std(PLS_accu['NP_pos'])
Accuracy_std['NGP_pos_1_13'] = np.std(PLS_accu['NGP_pos'])
Accuracy_std['bin_pos_1_13'] = np.std(PLS_accu['bin_pos'])

# %%
Score_std = {}
Score_std['P_neg_1_13'] = np.std(PLS_score['P_neg'])
Score_std['NP_neg_1_13'] = np.std(PLS_score['NP_neg'])
Score_std['NGP_neg_1_13'] = np.std(PLS_score['NGP_neg'])
Score_std['bin_neg_1_13'] = np.std(PLS_score['bin_neg'])
Score_std['P_pos_1_13'] = np.std(PLS_score['P_pos'])
Score_std['NP_pos_1_13'] = np.std(PLS_score['NP_pos'])
Score_std['NGP_pos_1_13'] = np.std(PLS_score['NGP_pos'])
Score_std['bin_pos_1_13'] = np.std(PLS_score['bin_pos'])

# %%
Accuracy_H = pd.DataFrame(list(Accuracy.values()), index = Accuracy.keys(), columns  = ['Accuracy']).T
Accuracy_H.loc['SD'] = list(Accuracy_std.values())
Accuracy_H.T
# Out:
#               Accuracy        SD
# P_neg_1_13    0.935385  0.017941
# NP_neg_1_13   0.922051  0.018462
# NGP_neg_1_13  0.950769  0.028937
# bin_neg_1_13  0.976410  0.006956
# P_pos_1_13    0.855385  0.034690
# NP_pos_1_13   0.969231  0.021757
# NGP_pos_1_13  0.976410  0.006956
# bin_pos_1_13  1.000000  0.000000

# %%
Score_H = pd.DataFrame(list(Score.values()), index = Score.keys(), columns  = ['Score']).T
Score_H.loc['SD'] = list(Score_std.values())
Score_H.T
# Out:
#                  Score        SD
# P_neg_1_13    0.152057  0.137269
# NP_neg_1_13   0.725546  0.015854
# NGP_neg_1_13  0.666487  0.108481
# bin_neg_1_13  0.841547  0.004608
# P_pos_1_13    0.237148  0.121586
# NP_pos_1_13   0.597396  0.020166
# NGP_pos_1_13  0.765408  0.009334
# bin_pos_1_13  0.769830  0.005567

# %% [markdown]
# ### Characteristics of the most important features

# %% [markdown]
# The characteristics of the most important features for each of the methods is done by the same process as applied in the random forests section of the notebook.

# %%
#Getting the number of samples, groups, ratios for each important feature, magnitude for most important feature 
Imp_feat = (PLS_weights, PLS_RegCoef)
ev = []
magni = []
index = []
for m in Imp_feat:
    for j in m:
        if j.endswith('neg'):
            Spectra = aligned_all_neg2
        elif j.endswith('pos'):
            Spectra = aligned_all_pos2
        index.append(j)
        ratio = []
        nsamples = []
        n_groups = []
        number = round(0.02*len(Spectra))
        total_m = 0
        for i in range(len(m[j])):
            total_m = total_m + m[j][i][1]
        magni.append(m[j][0][1]/(total_m/len(Spectra)))
        for i in range(number): 
            ngroups = {}
            line = Spectra.data.loc[m[j][i][2],:].notnull()
            nsamples.append(line.sum())
            for n in range(len(line)):
                if line[n] == True:
                    ngroups[Spectra.labels[n]] = 1
            n_groups.append(sum(list((ngroups.values()))))
            ratio.append(nsamples[-1]/n_groups[-1])
        df = pd.DataFrame(columns = ['nsamples', 'n_groups', 'ratio'])
        df['nsamples'] = nsamples
        df['n_groups'] = n_groups
        df['ratio']  = ratio
        ev.append(df)

# %%
#Calculating averages of number of samples, groups and ratios and storing information in a DataFrame
ratio_m = []
samples_m = []
groups_m = []
for i in range(len(ev)):
    samples_m.append(np.mean(ev[i].iloc[:,0]))
    groups_m.append(np.mean(ev[i].iloc[:,1]))
    ratio_m.append(np.mean(ev[i].iloc[:,2]))
df = pd.DataFrame(columns = ['samples_m', 'groups_m', 'ratio_m'], index = index)
df['samples_m'] = samples_m
df['groups_m'] = groups_m
df['ratio_m'] = ratio_m
#print(df)
#Inserting blank lines in the DataFrame for better presentation and separation
line = pd.DataFrame({"samples_m": None, "groups_m": None, 'ratio_m':None}, index=[''])
df = pd.concat([df.iloc[:8], line, df.iloc[8:]])

# %%
f, ax = plt.subplots(figsize=(12, 9))
hm = sns.heatmap(df, annot=True, ax=ax, cmap = sns.cm.rocket_r)
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.text(1.5,-0.5,'PLS_Weights',horizontalalignment='center', verticalalignment='center')
plt.text(1.5,8.5,'PLS_RegCoef',horizontalalignment='center', verticalalignment='center')
plt.show()

# %%
print('Magnitude of most important features for each case:')
print(magni)
# Out:
# Magnitude of most important features for each case:
# [2.3547053753943294, 2.26016884200847, 1.743158143104398, 1.7238130946660812, 3.4382091521287212, 2.353815985716451, 1.8697841291682256, 2.1455354727096747, 5.731681806293541, 4.4959326747505015, 3.7144642587533983, 2.811850343572156, 9.847249477384597, 5.571567848207076, 4.948678350574445, 4.109527566177878]

# %% [markdown]
# ### Model with the full dataset and sample representation on the two most important Components/Latent Variables
#
# NGP data treatment for the negative mode

# %%
from sklearn.cross_decomposition import PLSRegression

# %%
plsda = PLSRegression(n_components = 15)
#Fitting the model and getting the X_scores
plsda.fit(X=Euc_NGP_neg2.data.T,Y=matrix)
LV_score = pd.DataFrame(plsda.x_scores_)

#Preparing colours to separate different groups
colours = cm.get_cmap('nipy_spectral', 13)
col_lbl = colours(range(13))
col_lbl = list(col_lbl)
for i in range(len(col_lbl)):
    a = 3*i
    col_lbl.insert(a+1,col_lbl[a])
    col_lbl.insert(a+2,col_lbl[a])

    #Scatter plot
ax = LV_score.iloc[:,0:2].plot(x=0, y=1, kind='scatter', s=50, alpha=0.7, c = col_lbl, figsize=(9,9))
#Labeling each point
i = -1
for n, x in enumerate(LV_score.values): 
    if n%3 == 0:
        i = i + 1
        label = Spectra.unique_labels()[i]
                #label = LV_score.index.values[n]
    ax.text(x[0],x[1],label, fontsize = 8)

# %% [markdown]
# Binary processed data for the negative mode

# %%
plsda = PLSRegression(n_components = 15)
#Fitting the model and getting the X_scores
plsda.fit(X=binary_neg2.data.T,Y=matrix)
LV_score = pd.DataFrame(plsda.x_scores_)

#Preparing colours to separate different groups
colours = cm.get_cmap('nipy_spectral', 13)
col_lbl = colours(range(13))
col_lbl = list(col_lbl)
for i in range(len(col_lbl)):
    a = 3*i
    col_lbl.insert(a+1,col_lbl[a])
    col_lbl.insert(a+2,col_lbl[a])

#Scatter plot
ax = LV_score.iloc[:,0:2].plot(x=0, y=1, kind='scatter', s=50, alpha=0.7, c = col_lbl, figsize=(9,9))
#Labeling each point
i = -1
for n, x in enumerate(LV_score.values): 
    if n%3 == 0:
        i = i + 1
        label = Spectra.unique_labels()[i]
                #label = LV_score.index.values[n]
    ax.text(x[0],x[1],label, fontsize = 8)
